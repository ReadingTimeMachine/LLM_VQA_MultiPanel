# %% [markdown]
# ## Claude.ai -- Updates!
#
# Push VQA to Claude.

# %% [markdown]
# ### Docs:
#
# * in theory, there is documentation here: https://docs.anthropic.com/en/home,
# * but in reality I just asked "Hey Claude.  How do I use your API through Python to upload an image and ask you questions about it?" followed by "Is there anyway to set the context?  For example, in chatgpt you have the ""role": "system", "content"" part of your message where you would say things like "You are a helpful assistant in charge of automating a process".  Or does one just incorporate that into the "question" part of the inputs?" and starting building from there
#
# #### Key Points (cp-claude)
#
# * API Key: Get your API key from the [Anthropic Console](https://console.anthropic.com/) and set it as an environment variable or pass it directly
# * Supported formats: JPEG, PNG, GIF, and WebP images
# * Model: Use `claude-sonnet-4-20250514` for Claude Sonnet 4
# * Size limits: Images should be under 5MB and no larger than 8000x8000 pixels

# %% [markdown]
# First, install anthropic api (also, see .yml file for the environment for this project)

# %%
#!pip install anthropic

# %% [markdown]
# Where are things stored/going to be stored?

# %%
dir_api_old = '/Users/jnaiman/Downloads/tmp/iConf2025/visual_qa_multipanel/LMM_outputs/claude_api/' #store API results for example data
dir_api = '/Users/jnaiman/Downloads/tmp/iConf2025/tmpMultipanel/LMM_outputs/claude_api/' #store API results for example data

model ="claude-sonnet-4-20250514"

redo_file = '/Users/jnaiman/Downloads/tmp/iConf2025/tmpMultipanel/question_updates.json'

# where is VQA dataset?
jsons_dir = '/Users/jnaiman/Downloads/tmp/iConf2025/visual_qa_multipanel/jsons/' # directory where jsons created with figure are stored
imgs_dir = '/Users/jnaiman/Downloads/tmp/iConf2025/visual_qa_multipanel/imgs/' # where images are stored

# other stuff, where stored?
key_file = '/Users/jnaiman/.claudeai/key.txt'
# for saving temp images for reading in
tmp_dir = '/Users/jnaiman/Downloads/tmp/'

img_format = 'png'

# %%
import anthropic
import base64
from PIL import Image
import numpy as np
import json
import re
import pickle
import os
from glob import glob

# debug
from importlib import reload
from anthropic import RateLimitError


from sys import path
path.append('../')
import utils.llm_utils
reload(utils.llm_utils)
from utils.llm_utils import parse_qa, load_image, get_img_json_pair, parse_for_errors

import time
from utils.plot_qa_utils import get_nplots
from copy import deepcopy

# %%
# setup
with open(key_file,'r') as f:
    api_key = f.read()

client = anthropic.Anthropic(
  api_key=api_key.strip(),  # this is also the default, it can be omitted
)

# %%
jsons_to_parse = glob(jsons_dir + '/*.json')
jsons_to_parse[:3]
# Out:
# ['/Users/jnaiman/Downloads/tmp/iConf2025/visual_qa_multipanel/jsons/Picture186.json',
#  '/Users/jnaiman/Downloads/tmp/iConf2025/visual_qa_multipanel/jsons/Picture169.json',
#  '/Users/jnaiman/Downloads/tmp/iConf2025/visual_qa_multipanel/jsons/Picture56.json']

# %%
def send_to_claude(question_list, client, image_path, encoded_image,
                    model="claude-sonnet-4-20250514",
                    max_tokens=1000, temperature=0.1,
                    media_type = 'image/png',
                    tmp_dir = '/Users/jnaiman/Downloads/tmp/',
                    test_run = True, fac=1.0, 
                    verbose=True, verbose_tokens = False,
                    system_prompt = None, 
                    max_retries = 10, sleep_time=1):
    """
    Sends the question to claude and collects response.clear

    system_prompt : if None, then defaults to the overall system prompt generated with the questions.
    """
    if system_prompt is None:
        system_prompt = question_list['persona']

    #print('system prompt:', system_prompt)

    iFac = 2.0
    success = False
    #['persona', 'context','question', 'format']
    attempt = 0
    while not success and attempt < max_retries:
        try:
            question = question_list['context'] + " " + question_list['question'] + " " + question_list['format']
            # lowercase the first word, just in case
            question = question.lstrip() # no whitespace
            question = question[0].lower() + question[1:]
            if verbose: print('   on question:',question)
            # Prepare the API request
            prompt = f"I am going to show you an image. Now, {question}"
            prompt_save = f"I am going to show you an image. Now, {question}"
            ##question_list['prompt'] = prompt
            
            if not test_run:
                # Send the request to the Claude api
                response = client.messages.create(
                    model = model,
                    max_tokens=max_tokens,
                    system = system_prompt,
                    temperature=temperature,
                    messages=[
                        {
                            "role": "user",
                            "content": [
                                {
                                    "type": "image",
                                    "source": {
                                        "type": "base64",
                                        "media_type": media_type,
                                        "data": encoded_image,
                                    },
                                },
                                {
                                    "type": "text",
                                    "text": prompt
                                }
                            ],
                        }
                    ]
                )
                success = True
            else:
                success = True
        except RateLimitError as e:
            if attempt < max_retries - 1:
                # Exponential backoff with jitter
                wait_time = sleep_time*(2 ** (attempt)) + np.random.uniform(0, 1)
                print(f"      Rate limit hit. Waiting {wait_time:.2f} seconds before retry {attempt + 1}")
                time.sleep(wait_time)
                attempt += 1
            else:
                print(f"Max retries exceeded. Error: {e}")
                raise
        except Exception as e:
            print(e)
            new_fac = fac/iFac
            print('      new fac = ', new_fac)
            encoded_image = load_image(image_path,fac=new_fac, tmp_dir=tmp_dir)
            iFac += 1
    
    #print(response)
    if not test_run:
        # Get the response from the API
        answer = response.content[0].text #response.choices[0].message.content
        question_list['raw answer'] = answer
        # also calculate usage
        usage = response.usage
        question_list['usage'] = usage
        if verbose and verbose_tokens:
            print(f"      - Input tokens: {usage.input_tokens}")
            print(f"      - Output tokens: {usage.output_tokens}")
            print(f"      - Total tokens: {usage.input_tokens + usage.output_tokens}")
        # format answer
        answer_format = answer.split('```json"')[-1].split('\n')[0].replace('\n', '')
        #answer.replace("```json\n",'').replace("\n```",'')
        try:
            question_list['Response'] = json.loads(answer_format)
        except:
            question_list['Response'] = answer_format
            question_list['Error'] = 'JSON formatting'
        question_list['Response String'] = answer_format
        success = True
    else:
        question_list['Response'] = 'TEST RUN'
        question_list['Response String'] = 'TEST RUN'
        question_list['raw answer'] = 'TEST RUN'

    return question_list, prompt_save, system_prompt

# %%
with open(redo_file,'r') as f:
    redo_q_list = json.load(f)
    redo_q_list = json.loads(redo_q_list)

questions_redo = []
for q in redo_q_list:
    questions_redo.append(q['old'])

redo_q_list, questions_redo
# Out:
# ([{'key': 'aspect ratio',
#    'old': 'You are a helpful assistant that can analyze images.  What is the aspect ratio of this figure? You are a helpful assistant, please format the output as a json as {"aspect ratio":""} to store the aspect ratio of the plot.',
#    'new': 'You are a helpful assistant that can analyze images.  What is the aspect ratio of this figure? Please format the output as a json as {"aspect ratio":""} to store the aspect ratio of the plot.',
#    'new format': 'Please format the output as a json as {"aspect ratio":""} to store the aspect ratio of the plot.',
#    'new question': 'What is the aspect ratio of this figure?',
#    'new context': ''},
#   {'key': 'ylabels',
#    'old': 'You are a helpful assistant that can analyze images.  What are the x-axis titles for each figure panel? Please format the output as a json as {"ylabels":[]}, where the list is a list of strings of all of the y-axis titles. If there is a single plot, this should be one element in this list, and if there are multiple plots the list should be in row-major (C-style) order. If a plot does not have an y-axis title, then denote this by an empty string in the list.  Please format any formulas in the title in a Python LaTeX string (for example \'Light $\\\\alpha$\'). ',
#    'new': 'You are a helpful assistant that can analyze images.  What are the y-axis titles for each figure panel? Please format the output as a json as {"ylabels":[]}, where the list is a list of strings of all of the y-axis titles. If there is a single plot, this should be one element in this list, and if there are multiple plots the list should be in row-major (C-style) order. If a plot does not have an y-axis title, then denote this by an empty string in the list.  Please format any formulas in the title in a Python LaTeX string (for example \'Light $\\\\alpha$\'). ',
#    'new format': 'Please format the output as a json as {"ylabels":[]}, where the list is a list of strings of all of the y-axis titles. If there is a single plot, this should be one element in this list, and if there are multiple plots the list should be in row-major (C-style) order. If a plot does not have an y-axis title, then denote this by an empty string in the list.  Please format any formulas in the title in a Python LaTeX string (for example \'Light $\\\\alpha$\'). ',
#    'new question': 'What are the y-axis titles for each figure panel?',
#    'new context': ''},
#   {'key': 'distribution-color (words + list)',
#    'old': 'You are a helpful assistant that can analyze images. The following question refers to the plot in the top row and second from the left panel. What is the underlying distribution used to create the data in this figure panel along the color-axis? Please format the output as a json as {"distribution color":""} for this figure panel, where the "distribution color" value should be a string, calculated from the data values used to create the plot. Please choose the distribution from the following list: [random, linear, gaussian mixture model].',
#    'new': 'You are a helpful assistant that can analyze images. The following question refers to the plot in the top row and second from the left panel. Please choose the distribution from the following list: [random, linear, gaussian mixture model]. What is the underlying distribution used to create the data in this figure panel along the color-axis? Please format the output as a json as {"distribution color":""} for this figure panel, where the "distribution color" value should be a string, calculated from the data values used to create the plot.',
#    'new format': 'Please format the output as a json as {"distribution color":""} for this figure panel, where the "distribution color" value should be a string, calculated from the data values used to create the plot.',
#    'new question': 'What is the underlying distribution used to create the data in this figure panel along the color-axis?',
#    'new context': 'The following question refers to the plot in the top row and second from the left panel. Please choose the distribution from the following list: [random, linear, gaussian mixture model].'},
#   {'key': 'distribution-color (words + list)',
#    'old': 'You are a helpful assistant that can analyze images. The following question refers to the plot in the second row and left-most panel. What is the underlying distribution used to create the data in this figure panel along the color-axis? Please format the output as a json as {"distribution color":""} for this figure panel, where the "distribution color" value should be a string, calculated from the data values used to create the plot. Please choose the distribution from the following list: [random, linear, gaussian mixture model].',
#    'new': 'You are a helpful assistant that can analyze images. The following question refers to the plot in the second row and left-most panel. Please choose the distribution from the following list: [random, linear, gaussian mixture model]. What is the underlying distribution used to create the data in this figure panel along the color-axis? Please format the output as a json as {"distribution color":""} for this figure panel, where the "distribution color" value should be a string, calculated from the data values used to create the plot.',
#    'new format': 'Please format the output as a json as {"distribution color":""} for this figure panel, where the "distribution color" value should be a string, calculated from the data values used to create the plot.',
#    'new question': 'What is the underlying distribution used to create the data in this figure panel along the color-axis?',
#    'new context': 'The following question refers to the plot in the second row and left-most panel. Please choose the distribution from the following list: [random, linear, gaussian mixture model].'},
#   {'key': 'distribution-color (words + list)',
#    'old': 'You are a helpful assistant that can analyze images. The following question refers to the plot in the third row and second column panel. What is the underlying distribution used to create the data in this figure panel along the color-axis? Please format the output as a json as {"distribution color":""} for this figure panel, where the "distribution color" value should be a string, calculated from the data values used to create the plot. Please choose the distribution from the following list: [random, linear, gaussian mixture model].',
#    'new': 'You are a helpful assistant that can analyze images. The following question refers to the plot in the third row and second column panel. Please choose the distribution from the following list: [random, linear, gaussian mixture model]. What is the underlying distribution used to create the data in this figure panel along the color-axis? Please format the output as a json as {"distribution color":""} for this figure panel, where the "distribution color" value should be a string, calculated from the data values used to create the plot.',
#    'new format': 'Please format the output as a json as {"distribution color":""} for this figure panel, where the "distribution color" value should be a string, calculated from the data values used to create the plot.',
#    'new question': 'What is the underlying distribution used to create the data in this figure panel along the color-axis?',
#    'new context': 'The following question refers to the plot in the third row and second column panel. Please choose the distribution from the following list: [random, linear, gaussian mixture model].'},
#   {'key': 'distribution-color (words + list)',
#    'old': 'You are a helpful assistant that can analyze images. The following question refers to the plot in the fourth row and third column panel. What is the underlying distribution used to create the data in this figure panel along the color-axis? Please format the output as a json as {"distribution color":""} for this figure panel, where the "distribution color" value should be a string, calculated from the data values used to create the plot. Please choose the distribution from the following list: [random, linear, gaussian mixture model].',
#    'new': 'You are a helpful assistant that can analyze images. The following question refers to the plot in the fourth row and third column panel. Please choose the distribution from the following list: [random, linear, gaussian mixture model]. What is the underlying distribution used to create the data in this figure panel along the color-axis? Please format the output as a json as {"distribution color":""} for this figure panel, where the "distribution color" value should be a string, calculated from the data values used to create the plot.',
#    'new format': 'Please format the output as a json as {"distribution color":""} for this figure panel, where the "distribution color" value should be a string, calculated from the data values used to create the plot.',
#    'new question': 'What is the underlying distribution used to create the data in this figure panel along the color-axis?',
#    'new context': 'The following question refers to the plot in the fourth row and third column panel. Please choose the distribution from the following list: [random, linear, gaussian mixture model].'},
#   {'key': 'distribution-x/y (words + list)',
#    'old': 'You are a helpful assistant that can analyze images. The following question refers to the plot in the top row and second from the left panel. What is the underlying distribution used to create the data in this figure panel in the x/y-plane? Please format the output as a json as {"distribution x/y":""} for this figure panel, where the "distribution x/y" value should be a string, calculated from the data values used to create the plot. Please choose the distribution from the following list: [random, linear, gaussian mixture model].',
#    'new': 'You are a helpful assistant that can analyze images. The following question refers to the plot in the top row and second from the left panel. Please choose the distribution from the following list: [random, linear, gaussian mixture model]. What is the underlying distribution used to create the data in this figure panel in the x/y-plane? Please format the output as a json as {"distribution x/y":""} for this figure panel, where the "distribution x/y" value should be a string, calculated from the data values used to create the plot.',
#    'new format': 'Please format the output as a json as {"distribution x/y":""} for this figure panel, where the "distribution x/y" value should be a string, calculated from the data values used to create the plot.',
#    'new question': 'What is the underlying distribution used to create the data in this figure panel in the x/y-plane?',
#    'new context': 'The following question refers to the plot in the top row and second from the left panel. Please choose the distribution from the following list: [random, linear, gaussian mixture model].'},
#   {'key': 'distribution-x/y (words + list)',
#    'old': 'You are a helpful assistant that can analyze images. The following question refers to the plot in the second row and left-most panel. What is the underlying distribution used to create the data in this figure panel in the x/y-plane? Please format the output as a json as {"distribution x/y":""} for this figure panel, where the "distribution x/y" value should be a string, calculated from the data values used to create the plot. Please choose the distribution from the following list: [random, linear, gaussian mixture model].',
#    'new': 'You are a helpful assistant that can analyze images. The following question refers to the plot in the second row and left-most panel. Please choose the distribution from the following list: [random, linear, gaussian mixture model]. What is the underlying distribution used to create the data in this figure panel in the x/y-plane? Please format the output as a json as {"distribution x/y":""} for this figure panel, where the "distribution x/y" value should be a string, calculated from the data values used to create the plot.',
#    'new format': 'Please format the output as a json as {"distribution x/y":""} for this figure panel, where the "distribution x/y" value should be a string, calculated from the data values used to create the plot.',
#    'new question': 'What is the underlying distribution used to create the data in this figure panel in the x/y-plane?',
#    'new context': 'The following question refers to the plot in the second row and left-most panel. Please choose the distribution from the following list: [random, linear, gaussian mixture model].'},
#   {'key': 'distribution-x/y (words + list)',
#    'old': 'You are a helpful assistant that can analyze images. The following question refers to the plot in the third row and second column panel. What is the underlying distribution used to create the data in this figure panel in the x/y-plane? Please format the output as a json as {"distribution x/y":""} for this figure panel, where the "distribution x/y" value should be a string, calculated from the data values used to create the plot. Please choose the distribution from the following list: [random, linear, gaussian mixture model].',
#    'new': 'You are a helpful assistant that can analyze images. The following question refers to the plot in the third row and second column panel. Please choose the distribution from the following list: [random, linear, gaussian mixture model]. What is the underlying distribution used to create the data in this figure panel in the x/y-plane? Please format the output as a json as {"distribution x/y":""} for this figure panel, where the "distribution x/y" value should be a string, calculated from the data values used to create the plot.',
#    'new format': 'Please format the output as a json as {"distribution x/y":""} for this figure panel, where the "distribution x/y" value should be a string, calculated from the data values used to create the plot.',
#    'new question': 'What is the underlying distribution used to create the data in this figure panel in the x/y-plane?',
#    'new context': 'The following question refers to the plot in the third row and second column panel. Please choose the distribution from the following list: [random, linear, gaussian mixture model].'},
#   {'key': 'distribution-x/y (words + list)',
#    'old': 'You are a helpful assistant that can analyze images. The following question refers to the plot in the fourth row and third column panel. What is the underlying distribution used to create the data in this figure panel in the x/y-plane? Please format the output as a json as {"distribution x/y":""} for this figure panel, where the "distribution x/y" value should be a string, calculated from the data values used to create the plot. Please choose the distribution from the following list: [random, linear, gaussian mixture model].',
#    'new': 'You are a helpful assistant that can analyze images. The following question refers to the plot in the fourth row and third column panel. Please choose the distribution from the following list: [random, linear, gaussian mixture model]. What is the underlying distribution used to create the data in this figure panel in the x/y-plane? Please format the output as a json as {"distribution x/y":""} for this figure panel, where the "distribution x/y" value should be a string, calculated from the data values used to create the plot.',
#    'new format': 'Please format the output as a json as {"distribution x/y":""} for this figure panel, where the "distribution x/y" value should be a string, calculated from the data values used to create the plot.',
#    'new question': 'What is the underlying distribution used to create the data in this figure panel in the x/y-plane?',
#    'new context': 'The following question refers to the plot in the fourth row and third column panel. Please choose the distribution from the following list: [random, linear, gaussian mixture model].'},
#   {'key': 'distribution- (words + list)',
#    'old': 'You are a helpful assistant that can analyze images. The following question refers to the plot in the fourth row and fourth column panel. What is the underlying distribution used to create the data in this figure panel? Please format the output as a json as {"distribution":""} for this figure panel, where the "distribution" value should be a string, calculated from the data values used to create the plot. Please choose the distribution from the following list: [random, linear, gaussian mixture model].',
#    'new': 'You are a helpful assistant that can analyze images. The following question refers to the plot in the fourth row and fourth column panel. Please choose the distribution from the following list: [random, linear, gaussian mixture model]. What is the underlying distribution used to create the data in this figure panel? Please format the output as a json as {"distribution":""} for this figure panel, where the "distribution" value should be a string, calculated from the data values used to create the plot.',
#    'new format': 'Please format the output as a json as {"distribution":""} for this figure panel, where the "distribution" value should be a string, calculated from the data values used to create the plot.',
#    'new question': 'What is the underlying distribution used to create the data in this figure panel?',
#    'new context': 'The following question refers to the plot in the fourth row and fourth column panel. Please choose the distribution from the following list: [random, linear, gaussian mixture model].'}],
#  ['You are a helpful assistant that can analyze images.  What is the aspect ratio of this figure? You are a helpful assistant, please format the output as a json as {"aspect ratio":""} to store the aspect ratio of the plot.',
#   'You are a helpful assistant that can analyze images.  What are the x-axis titles for each figure panel? Please format the output as a json as {"ylabels":[]}, where the list is a list of strings of all of the y-axis titles. If there is a single plot, this should be one element in this list, and if there are multiple plots the list should be in row-major (C-style) order. If a plot does not have an y-axis title, then denote this by an empty string in the list.  Please format any formulas in the title in a Python LaTeX string (for example \'Light $\\\\alpha$\'). ',
#   'You are a helpful assistant that can analyze images. The following question refers to the plot in the top row and second from the left panel. What is the underlying distribution used to create the data in this figure panel along the color-axis? Please format the output as a json as {"distribution color":""} for this figure panel, where the "distribution color" value should be a string, calculated from the data values used to create the plot. Please choose the distribution from the following list: [random, linear, gaussian mixture model].',
#   'You are a helpful assistant that can analyze images. The following question refers to the plot in the second row and left-most panel. What is the underlying distribution used to create the data in this figure panel along the color-axis? Please format the output as a json as {"distribution color":""} for this figure panel, where the "distribution color" value should be a string, calculated from the data values used to create the plot. Please choose the distribution from the following list: [random, linear, gaussian mixture model].',
#   'You are a helpful assistant that can analyze images. The following question refers to the plot in the third row and second column panel. What is the underlying distribution used to create the data in this figure panel along the color-axis? Please format the output as a json as {"distribution color":""} for this figure panel, where the "distribution color" value should be a string, calculated from the data values used to create the plot. Please choose the distribution from the following list: [random, linear, gaussian mixture model].',
#   'You are a helpful assistant that can analyze images. The following question refers to the plot in the fourth row and third column panel. What is the underlying distribution used to create the data in this figure panel along the color-axis? Please format the output as a json as {"distribution color":""} for this figure panel, where the "distribution color" value should be a string, calculated from the data values used to create the plot. Please choose the distribution from the following list: [random, linear, gaussian mixture model].',
#   'You are a helpful assistant that can analyze images. The following question refers to the plot in the top row and second from the left panel. What is the underlying distribution used to create the data in this figure panel in the x/y-plane? Please format the output as a json as {"distribution x/y":""} for this figure panel, where the "distribution x/y" value should be a string, calculated from the data values used to create the plot. Please choose the distribution from the following list: [random, linear, gaussian mixture model].',
#   'You are a helpful assistant that can analyze images. The following question refers to the plot in the second row and left-most panel. What is the underlying distribution used to create the data in this figure panel in the x/y-plane? Please format the output as a json as {"distribution x/y":""} for this figure panel, where the "distribution x/y" value should be a string, calculated from the data values used to create the plot. Please choose the distribution from the following list: [random, linear, gaussian mixture model].',
#   'You are a helpful assistant that can analyze images. The following question refers to the plot in the third row and second column panel. What is the underlying distribution used to create the data in this figure panel in the x/y-plane? Please format the output as a json as {"distribution x/y":""} for this figure panel, where the "distribution x/y" value should be a string, calculated from the data values used to create the plot. Please choose the distribution from the following list: [random, linear, gaussian mixture model].',
#   'You are a helpful assistant that can analyze images. The following question refers to the plot in the fourth row and third column panel. What is the underlying distribution used to create the data in this figure panel in the x/y-plane? Please format the output as a json as {"distribution x/y":""} for this figure panel, where the "distribution x/y" value should be a string, calculated from the data values used to create the plot. Please choose the distribution from the following list: [random, linear, gaussian mixture model].',
#   'You are a helpful assistant that can analyze images. The following question refers to the plot in the fourth row and fourth column panel. What is the underlying distribution used to create the data in this figure panel? Please format the output as a json as {"distribution":""} for this figure panel, where the "distribution" value should be a string, calculated from the data values used to create the plot. Please choose the distribution from the following list: [random, linear, gaussian mixture model].'])

# %%
iMax = 2
verbose = False
test_run = False # run w/o actually pinging openai
restart = False
max_tokens=500
# set system_prompt to None to default to what is in question list
system_prompt = """You are a helpful assistant that responds only in valid JSON format. Do not include any explanations, reasoning, or text outside of the JSON response."""
#system_prompt = """You must respond with only valid JSON. Start your response immediately with { and end with }. Do not write any text before or after the JSON."""
temperature=0.1
fac = 1.0
sleep = 5 # seconds
use_single_prompt = True # use 1 prompt and 1 image, if False will use multiple at a time

max_img_size = (8000,8000)

import utils.llm_utils
reload(utils.llm_utils)
from utils.llm_utils import get_img_json_pair

if test_run:
    sleep = 0.0

for ijson,json_path in enumerate(jsons_to_parse):
    if ijson >= iMax:
        continue

    print('on', ijson, 'of', min(iMax,len(jsons_to_parse)))

    # get image and base json
    img_path = imgs_dir + json_path.split('/')[-1].removesuffix('.json') + '.' + img_format
    print(img_path)
    encoded_image, img_format_media, base_json, err = get_img_json_pair(img_path, json_path, dir_api, 
                                                      fac=fac, restart=restart,
                                                      tmp_dir=tmp_dir, max_img_size=max_img_size)
    if err:
        continue

    ###### create QA ########

    # also load the already-filled json from prior run
    with open(dir_api_old + json_path.split('/')[-1].removesuffix('.json') + '.pickle', 'rb') as f:
        qa_orig, model = pickle.load(f)

    # find ones to rerun
    qa = []; redos = []
    for qa_pair in qa_orig:
        if qa_pair['Q'] in questions_redo:
            Qnew = redo_q_list[questions_redo.index(qa_pair['Q'])]
            print('** REDO:', qa_pair['Q'])
            qaout = deepcopy(qa_pair)
            # empty things
            for k in ['Response', 'raw answer', 'Response String', 'prompt']:
                qaout[k] = ""
            qaout['fac'] = 1.0
            # update question
            qaout['Q'] = Qnew['new']
            qaout['format'] = Qnew['new format']
            qaout['question'] = Qnew['new question']
            qa.append(qaout)
            redos.append(True)
            print('** NEW: ', qaout)
            #import sys; sys.exit()
        else:
            qa.append(deepcopy(qa_pair))
            redos.append(False)

    responses = []; prompts = []; system_prompts = []
    if use_single_prompt:
        for question_list,rd in zip(qa,redos):
            if rd:
                response, prompt, system_prompt_out = send_to_claude(question_list, client, img_path, encoded_image,
                            model = model, max_tokens=max_tokens, media_type='image/' + img_format_media,
                            test_run = test_run, system_prompt=system_prompt, temperature=temperature, 
                            sleep_time=sleep, fac=fac)
                responses.append(response)
                question_list['prompt'] = prompt
                question_list['system prompt'] = system_prompt_out
            else:
                responses.append(deepcopy(question_list['Response']))
        #import sys; sys.exit() # just do one
        time.sleep(sleep)
    time.sleep(sleep)

    # parse for errors
    #qa = parse_for_errors(qa, llm='claude')
    print('')
    print('**** Cleaned QA ****')
    #qa = parse_for_errors_claude(qa)
    qa = parse_for_errors(qa, llm='Claude')

    # dump to file
    if not test_run:
        with open(dir_api + json_path.split('/')[-1].removesuffix('.json')+ '.pickle', 'wb') as ff:
            pickle.dump([qa, model], ff)
        print('Just saved:', dir_api + json_path.split('/')[-1].removesuffix('.json')+ '.pickle')
    else:
        print('Would store at:', dir_api + json_path.split('/')[-1].removesuffix('.json')+ '.pickle')
    #import sys; sys.exit()
# Out:
# on 0 of 2
# /Users/jnaiman/Downloads/tmp/iConf2025/visual_qa_multipanel/imgs/Picture186.png
# ** REDO: You are a helpful assistant that can analyze images.  What is the aspect ratio of this figure? You are a helpful assistant, please format the output as a json as {"aspect ratio":""} to store the aspect ratio of the plot.
# ** NEW:  {'Q': 'You are a helpful assistant that can analyze images.  What is the aspect ratio of this figure? Please format the output as a json as {"aspect ratio":""} to store the aspect ratio of the plot.', 'A': {'aspect ratio': 0.9749596760962769}, 'Level': 'Level 1', 'type': 'Figure-level questions', 'Response': '', 'persona': 'You are a helpful assistant that can analyze images.', 'context': '', 'question': 'What is the aspect ratio of this figure?', 'format': 'Please format the output as a json as {"aspect ratio":""} to store the aspect ratio of the plot.', 'raw answer': '', 'usage': Usage(cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=1650, output_tokens=17, server_tool_use=None, service_tier='standard', cache_creation={'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}), 'Response String': '', 'prompt': '', 'system prompt': 'You are a helpful assistant that responds only in valid JSON format. Do not include any explanations, reasoning, or text outside of the JSON response.', 'fac': 1.0}
# ** REDO: You are a helpful assistant that can analyze images.  What are the x-axis titles for each figure panel? Please format the output as a json as {"ylabels":[]}, where the list is a list of strings of all of the y-axis titles. If there is a single plot, this should be one element in this list, and if there are multiple plots the list should be in row-major (C-style) order. If a plot does not have an y-axis title, then denote this by an empty string in the list.  Please format any formulas in the title in a Python LaTeX string (for example 'Light $\\alpha$').
# ** NEW:  {'Q': 'You are a helpful assistant that can analyze images.  What are the y-axis titles for each figure panel? Please format the output as a json as {"ylabels":[]}, where the list is a list of strings of all of the y-axis titles. If there is a single plot, this should be one element in this list, and if there are multiple plots the list should be in row-major (C-style) order. If a plot does not have an y-axis title, then denote this by an empty string in the list.  Please format any formulas in the title in a Python LaTeX string (for example \'Light $\\\\alpha$\'). ', 'A': {'ylabels': ['Den', 'Schechter Tracer Statistics', 'Reproduces $y-z$ ', 'Foundation Table', 'sake derivation tools', 'MAPS JET', 'List', '$\\sim1\\:M_\\odot$  Globular', 'WATER', 'Donor Nsf $FDF=1.38$ ', 'IDEAS', 'LENSES $r-i\\approx0.2$  $\\bar{\\Theta}_{\\rm i}$ ', 'ORION', 'Episode $\\beta = -2.70\\pm0.05$  $P\\lesssim400$ ', '$m_q = 5.5\\,$ ', 'count overview maps']}, 'Level': 'Level 1', 'type': 'Figure-level questions', 'Response': '', 'persona': 'You are a helpful assistant that can analyze images.', 'context': '', 'question': 'What are the y-axis titles for each figure panel?', 'format': 'Please format the output as a json as {"ylabels":[]}, where the list is a list of strings of all of the y-axis titles. If there is a single plot, this should be one element in this list, and if there are multiple plots the list should be in row-major (C-style) order. If a plot does not have an y-axis title, then denote this by an empty string in the list.  Please format any formulas in the title in a Python LaTeX string (for example \'Light $\\\\alpha$\'). ', 'raw answer': '', 'usage': Usage(cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=1745, output_tokens=108, server_tool_use=None, service_tier='standard', cache_creation={'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}), 'Response String': '', 'prompt': '', 'system prompt': 'You are a helpful assistant that responds only in valid JSON format. Do not include any explanations, reasoning, or text outside of the JSON response.', 'fac': 1.0}
# ** REDO: You are a helpful assistant that can analyze images. The following question refers to the plot in the fourth row and fourth column panel. What is the underlying distribution used to create the data in this figure panel? Please format the output as a json as {"distribution":""} for this figure panel, where the "distribution" value should be a string, calculated from the data values used to create the plot. Please choose the distribution from the following list: [random, linear, gaussian mixture model].
# ** NEW:  {'Q': 'You are a helpful assistant that can analyze images. The following question refers to the plot in the fourth row and fourth column panel. Please choose the distribution from the following list: [random, linear, gaussian mixture model]. What is the underlying distribution used to create the data in this figure panel? Please format the output as a json as {"distribution":""} for this figure panel, where the "distribution" value should be a string, calculated from the data values used to create the plot.', 'A': 'random', 'Level': 'Level 3', 'type': 'Plot-level questions', 'Response': '', 'persona': 'You are a helpful assistant that can analyze images.', 'context': 'The following question refers to the plot in the fourth row and fourth column panel.', 'question': 'What is the underlying distribution used to create the data in this figure panel?', 'format': 'Please format the output as a json as {"distribution":""} for this figure panel, where the "distribution" value should be a string, calculated from the data values used to create the plot.', 'plot number': 'plot15', 'raw answer': '', 'usage': Usage(cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=1701, output_tokens=16, server_tool_use=None, service_tier='standard', cache_creation={'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}), 'Response String': '', 'prompt': '', 'system prompt': 'You are a helpful assistant that responds only in valid JSON format. Do not include any explanations, reasoning, or text outside of the JSON response.', 'fac': 1.0}
# ** REDO: You are a helpful assistant that can analyze images. The following question refers to the plot in the fourth row and third column panel. What is the underlying distribution used to create the data in this figure panel along the color-axis? Please format the output as a json as {"distribution color":""} for this figure panel, where the "distribution color" value should be a string, calculated from the data values used to create the plot. Please choose the distribution from the following list: [random, linear, gaussian mixture model].
# ** NEW:  {'Q': 'You are a helpful assistant that can analyze images. The following question refers to the plot in the fourth row and third column panel. Please choose the distribution from the following list: [random, linear, gaussian mixture model]. What is the underlying distribution used to create the data in this figure panel along the color-axis? Please format the output as a json as {"distribution color":""} for this figure panel, where the "distribution color" value should be a string, calculated from the data values used to create the plot.', 'A': 'random', 'Level': 'Level 3', 'type': 'Plot-level questions', 'Response': '', 'persona': 'You are a helpful assistant that can analyze images.', 'context': 'The following question refers to the plot in the fourth row and third column panel.', 'question': 'What is the underlying distribution used to create the data in this figure panel along the color-axis?', 'format': 'Please format the output as a json as {"distribution color":""} for this figure panel, where the "distribution color" value should be a string, calculated from the data values used to create the plot.', 'plot number': 'plot1', 'raw answer': '', 'usage': Usage(cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=1708, output_tokens=17, server_tool_use=None, service_tier='standard', cache_creation={'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}), 'Response String': '', 'prompt': '', 'system prompt': 'You are a helpful assistant that responds only in valid JSON format. Do not include any explanations, reasoning, or text outside of the JSON response.', 'fac': 1.0}
# ** REDO: You are a helpful assistant that can analyze images. The following question refers to the plot in the fourth row and third column panel. What is the underlying distribution used to create the data in this figure panel in the x/y-plane? Please format the output as a json as {"distribution x/y":""} for this figure panel, where the "distribution x/y" value should be a string, calculated from the data values used to create the plot. Please choose the distribution from the following list: [random, linear, gaussian mixture model].
# ** NEW:  {'Q': 'You are a helpful assistant that can analyze images. The following question refers to the plot in the fourth row and third column panel. Please choose the distribution from the following list: [random, linear, gaussian mixture model]. What is the underlying distribution used to create the data in this figure panel in the x/y-plane? Please format the output as a json as {"distribution x/y":""} for this figure panel, where the "distribution x/y" value should be a string, calculated from the data values used to create the plot.', 'A': 'random', 'Level': 'Level 3', 'type': 'Plot-level questions', 'Response': '', 'persona': 'You are a helpful assistant that can analyze images.', 'context': 'The following question refers to the plot in the fourth row and third column panel.', 'question': 'What is the underlying distribution used to create the data in this figure panel in the x/y-plane?', 'format': 'Please format the output as a json as {"distribution x/y":""} for this figure panel, where the "distribution x/y" value should be a string, calculated from the data values used to create the plot.', 'plot number': 'plot1', 'raw answer': '', 'usage': Usage(cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=1714, output_tokens=19, server_tool_use=None, service_tier='standard', cache_creation={'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}), 'Response String': '', 'prompt': '', 'system prompt': 'You are a helpful assistant that responds only in valid JSON format. Do not include any explanations, reasoning, or text outside of the JSON response.', 'fac': 1.0}
#    on question: what is the aspect ratio of this figure? Please format the output as a json as {"aspect ratio":""} to store the aspect ratio of the plot.
#    on question: what are the y-axis titles for each figure panel? Please format the output as a json as {"ylabels":[]}, where the list is a list of strings of all of the y-axis titles. If there is a single plot, this should be one element in this list, and if there are multiple plots the list should be in row-major (C-style) order. If a plot does not have an y-axis title, then denote this by an empty string in the list.  Please format any formulas in the title in a Python LaTeX string (for example 'Light $\\alpha$').

# %% [markdown]
# ## Look at data
#
# Check out one, if you wanna:

# %%
pickles = glob(dir_api + '*.pickle')
pickles[:5]
# Out:
# ['/Users/jnaiman/Downloads/tmp/iConf2025/visual_qa_multipanel/LMM_outputs/claude_api/Picture11.pickle',
#  '/Users/jnaiman/Downloads/tmp/iConf2025/visual_qa_multipanel/LMM_outputs/claude_api/Picture182.pickle',
#  '/Users/jnaiman/Downloads/tmp/iConf2025/visual_qa_multipanel/LMM_outputs/claude_api/Picture72.pickle',
#  '/Users/jnaiman/Downloads/tmp/iConf2025/visual_qa_multipanel/LMM_outputs/claude_api/Picture190.pickle',
#  '/Users/jnaiman/Downloads/tmp/iConf2025/visual_qa_multipanel/LMM_outputs/claude_api/Picture60.pickle']

# %%
ifile = 0
with open(pickles[ifile], 'rb') as f:
    qa_in = pickle.load(f)[0]

# %%
qa_in[0]
# Out:
# {'Q': 'You are a helpful assistant that can analyze images.  How many panels are in this figure? Please format the output as a json as {"nrows":"", "ncols":""} to store the number of rows and columns.',
#  'A': {'nrows': 3, 'ncols': 3},
#  'Level': 'Level 1',
#  'type': 'Figure-level questions',
#  'Response': {'nrows': '3', 'ncols': '3'},
#  'persona': 'You are a helpful assistant that can analyze images.',
#  'context': '',
#  'question': 'How many panels are in this figure?',
#  'format': 'Please format the output as a json as {"nrows":"", "ncols":""} to store the number of rows and columns.',
#  'raw answer': '```json\n{"nrows": "3", "ncols": "3"}\n```',
#  'usage': Usage(cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=1264, output_tokens=22, server_tool_use=None, service_tier='standard', cache_creation={'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}),
#  'Response String': '```json',
#  'prompt': 'I am going to show you an image. Now, how many panels are in this figure? Please format the output as a json as {"nrows":"", "ncols":""} to store the number of rows and columns.',
#  'system prompt': 'You are a helpful assistant that responds only in valid JSON format. Do not include any explanations, reasoning, or text outside of the JSON response.'}

# %% [markdown]
# Claude outputs reasoning, so we have to do a bit of cleaning from the responses:

# %%
print(pickles[ifile])
print('*********')
for qa_pairs in qa_in:
    print('Prompt:', qa_pairs['prompt'])
    print('  Real A:', qa_pairs['A'])
    print('Claude A:', qa_pairs['Response'])
    print('')
# Out:
# /Users/jnaiman/Downloads/tmp/iConf2025/visual_qa_multipanel/LMM_outputs/claude_api/Picture11.pickle
# *********
# Prompt: I am going to show you an image. Now, how many panels are in this figure? Please format the output as a json as {"nrows":"", "ncols":""} to store the number of rows and columns.
#   Real A: {'nrows': 3, 'ncols': 3}
# Claude A: {'nrows': '3', 'ncols': '3'}
#
# Prompt: I am going to show you an image. Now, assume this is a figure made with matplotlib in Python.  Examples of plotting styles are "classic" or "ggplot". Examples of plotting styles are "classic" or "ggplot". What is the plot style used in this figure? Please format the output as a json as {"plot style":""} to store the matplotlib plotting style used in the figure.
#   Real A: {'plot style': 'Solarize_Light2'}
# Claude A: {'plot style': 'ggplot'}
#
# Prompt: I am going to show you an image. Now, assume this is a figure made with matplotlib in Python. Examples of matplotlib colormaps are "rainbow" or "Reds". What is the colormap that was used in this figure? Please format the output as a json as {"colormap":""} to store the matplotlib colormap used in the figure.
#   Real A: {'colormap': 'gray'}
# Claude A: {'colormap': 'viridis'}
#
# Prompt: I am going to show you an image. Now, what is the aspect ratio of this figure? You are a helpful assistant, please format the output as a json as {"aspect ratio":""} to store the aspect ratio of the plot.
#   Real A: {'aspect ratio': 0.3683256745788158}
# Claude A: {'aspect ratio': '3.5:1'}
#
# Prompt: I am going to show you an image. Now, what are the titles for each figure panel? Please format the output as a json as {"titles":[]}, where the list is a list of strings of all of the titles. If there is a single plot, this should be one element in this list, and if there are multiple plots the list should be in row-major (C-style) order. If a plot does not have a title, then denote this by an empty string in the list.  Please format any formulas in the title in a Python LaTeX string (for example 'Light $\\alpha$').
#   Real A: {'title': ['', '', '', '', '', 'BIASES CELLS SPITZER CURVE', '', 'CONTEXT', 'POSITION CAPTURES']}
# Claude A: {'titles': ['', '', '', '', '', '', 'CONTEXT', 'BIASES CELLS SPITZER CURVE', 'POSITION CAPTURES']}
#
# Prompt: I am going to show you an image. Now, what are the x-axis titles for each figure panel? Please format the output as a json as {"xlabels":[]}, where the list is a list of strings of all of the x-axis titles. If there is a single plot, this should be one element in this list, and if there are multiple plots the list should be in row-major (C-style) order. If a plot does not have an x-axis title, then denote this by an empty string in the list.  Please format any formulas in the title in a Python LaTeX string (for example 'Light $\\alpha$').
#   Real A: {'xlabels': ['Losses', '$|p|~l_{sh} \\ll 1$  SEDS', 'Definition', 'PREDICTS DURATION', 'INTERVAL PSPC SPOTS', '$R\\lesssim1-2\\;h^{-1}$ ', 'cme relationship convection', '$r_i=\\sqrt{a_i^2-b_i^2}$  visibility estimation', 'RECONCILE SPIN REDSHIFT']}
# Claude A: {'xlabels': ['Losses', '|p| l_sb << 1 SEDS', 'Definition', 'PREDICTS DURATION', 'INTERVAL PSPC SPOTS', 'R S-1 2h^{-1}', 'cme relationship connection', 'r_i = \\sqrt{a_i^2 - b_i^2} visibility estimation', 'RECONCILE SPIN REDSHIFT']}
#
# Prompt: I am going to show you an image. Now, what are the x-axis titles for each figure panel? Please format the output as a json as {"ylabels":[]}, where the list is a list of strings of all of the y-axis titles. If there is a single plot, this should be one element in this list, and if there are multiple plots the list should be in row-major (C-style) order. If a plot does not have an y-axis title, then denote this by an empty string in the list.  Please format any formulas in the title in a Python LaTeX string (for example 'Light $\\alpha$').
#   Real A: {'ylabels': ['Domain $\\mathcal{T}\\simeq1$ ', 'Quantity $20\\,{\\rm Myr}$ ', '$Z_{\\odot}$  network up', 'Areas $z_t = 1.7\\pm0.9.$  Vicinity', 'POINTS $\\omega^i=0$ ', 'VOLUME PLAY', 'ARCHIVE $(2.78 \\times 10^{30}$  CONDUCTION', 'Onset', '$\\sim0.1$  INTENSITY']}
# Claude A: {'ylabels': ['Domain 7', 'Quantity 20 Myr', 'Z network up', 'Vicinity', 'POINTS A = 0', 'VOLUME PLAY', 'ACTIVE [27.8 × 10^6 counts/s]', 'Onset', 'INTENSITY']}
#
# Prompt: I am going to show you an image. Now, what are the values for each of the tick marks on the x-axis? Please format the output as a json as {"xtick values":[[]]}, where each element of the outer list refers to a single panel, and each inner list is a list of the x-axis tick mark values. If there is a single plot, this should be one element in the outer list, and if there are multiple plots the outer list should be in row-major (C-style) order. If a plot does not have any x-axis tick values, then denote this by an empty string in the inner list.  Please format any formulas in the x-axis tick values in a Python LaTeX string (for example 'Light $\\alpha$').
#   Real A: {'xtick values': [['$\\mathdefault{-10^{6}}$', '$\\mathdefault{-10^{5}}$', '$\\mathdefault{-10^{4}}$', '$\\mathdefault{-10^{3}}$', '$\\mathdefault{-10^{2}}$', '$\\mathdefault{-10^{1}}$', '$\\mathdefault{-10^{0}}$', '$\\mathdefault{0}$', '$\\mathdefault{10^{0}}$', '$\\mathdefault{10^{1}}$', '$\\mathdefault{10^{2}}$', '$\\mathdefault{10^{3}}$', '$\\mathdefault{10^{4}}$', '$\\mathdefault{10^{5}}$', '$\\mathdefault{10^{6}}$'], ['$\\mathdefault{−3}$', '$\\mathdefault{−2}$', '$\\mathdefault{−1}$', '$\\mathdefault{0}$', '$\\mathdefault{1}$', '$\\mathdefault{2}$'], ['$\\mathdefault{−6}$', '$\\mathdefault{−4}$', '$\\mathdefault{−2}$', '$\\mathdefault{0}$', '$\\mathdefault{2}$'], ['$\\mathdefault{1}$', '$\\mathdefault{2}$', '$\\mathdefault{3}$', '$\\mathdefault{4}$', '$\\mathdefault{5}$'], ['$\\mathdefault{−7500}$', '$\\mathdefault{−5000}$', '$\\mathdefault{−2500}$', '$\\mathdefault{0}$', '$\\mathdefault{2500}$', '$\\mathdefault{5000}$', '$\\mathdefault{7500}$'], ['$\\mathdefault{−80}$', '$\\mathdefault{−60}$', '$\\mathdefault{−40}$', '$\\mathdefault{−20}$', '$\\mathdefault{0}$', '$\\mathdefault{20}$'], ['$\\mathdefault{1500}$', '$\\mathdefault{2000}$', '$\\mathdefault{2500}$', '$\\mathdefault{3000}$'], ['$\\mathdefault{−5}$', '$\\mathdefault{−4}$', '$\\mathdefault{−3}$', '$\\mathdefault{−2}$', '$\\mathdefault{−1}$', '$\\mathdefault{0}$'], ['$\\mathdefault{2.3}$', '$\\mathdefault{2.4}$', '$\\mathdefault{2.5}$', '$\\mathdefault{2.6}$', '$\\mathdefault{2.7}$']]}
# Claude A: {'xtick values': [['10^10', '10^8', '10^6', '10^4', '10^2', '10^0', '10^-2', '10^-4', '10^-6', '10^-8', '10^-10'], ['-2', '-1', '0', '1'], ['-4', '-2', '0'], ['1', '2', '3', '4'], ['-5000', '-2500', '0', '2500', '5000'], ['-60', '-40', '-20', '0'], ['1500', '2000', '2500'], ['-4', '-3', '-2', '-1', '0'], ['2.4', '2.5', '2.6']]}
#
# Prompt: I am going to show you an image. Now, what are the values for each of the tick marks on the y-axis? Please format the output as a json as {"ytick values":[[]]}, where each element of the outer list refers to a single panel, and each inner list is a list of the y-axis tick mark values. If there is a single plot, this should be one element in the outer list, and if there are multiple plots the outer list should be in row-major (C-style) order. If a plot does not have any y-axis tick values, then denote this by an empty string in the inner list.  Please format any formulas in the y-axis tick values in a Python LaTeX string (for example 'Light $\\alpha$').
#   Real A: {'ytick values': [['$\\mathdefault{−250000}$', '$\\mathdefault{0}$', '$\\mathdefault{250000}$', '$\\mathdefault{500000}$'], ['$\\mathdefault{−2500}$', '$\\mathdefault{0}$', '$\\mathdefault{2500}$', '$\\mathdefault{5000}$'], ['$\\mathdefault{−2500}$', '$\\mathdefault{0}$', '$\\mathdefault{2500}$', '$\\mathdefault{5000}$'], ['$\\mathdefault{−60}$', '$\\mathdefault{−40}$', '$\\mathdefault{−20}$', '$\\mathdefault{0}$'], ['$\\mathdefault{0}$', '$\\mathdefault{10}$', '$\\mathdefault{20}$'], ['$\\mathdefault{0}$', '$\\mathdefault{100}$', '$\\mathdefault{200}$'], ['$\\mathdefault{−4}$', '$\\mathdefault{−3}$', '$\\mathdefault{−2}$', '$\\mathdefault{−1}$', '$\\mathdefault{0}$'], ['$\\mathdefault{0}$', '$\\mathdefault{1}$', '$\\mathdefault{2}$'], ['$\\mathdefault{0}$', '$\\mathdefault{1}$', '$\\mathdefault{2}$']]}
# Claude A: {'ytick values': [['', '0', '250000'], ['0', '2500'], ['0', '2500'], ['', '-20', '', '-40'], ['10', '0'], ['100', '0'], ['', '-1', '-2', '-3'], ['1', '0'], ['1', '0']]}
#
# Prompt: I am going to show you an image. Now, please choose each plot type from the following list: [line, histogram, scatter]. What are the plot types for each panel in the figure? Please format the output as a json as {"plot types":[]}, where each element of the list refers to the plot type of a single panel. If there is a single plot, this should be one element in this list, and if there are multiple plots the list should be in row-major (C-style) order.
#   Real A: {'plot types': ['scatter', 'line', 'line', 'line', 'histogram', 'histogram', 'line', 'histogram', 'histogram']}
# Claude A: {'plot types': ['scatter', 'line', 'line', 'scatter', 'line', 'histogram', 'line', 'histogram', 'histogram']}
#
# Prompt: I am going to show you an image. Now, what are the plot types for each panel in the figure? Please format the output as a json as {"plot types":[]}, where each element of the list refers to the plot type of a single panel. If there is a single plot, this should be one element in this list, and if there are multiple plots the list should be in row-major (C-style) order.
#   Real A: {'plot types': ['scatter', 'line', 'line', 'line', 'histogram', 'histogram', 'line', 'histogram', 'histogram']}
# Claude A: {'plot types': ['scatter plot', 'line plot', 'line plot', 'scatter plot', 'line plot', 'histogram', 'line plot', 'histogram', 'bar plot']}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the third row and left-most panel. Please choose each linestyle from the following list: [-, --, :]. What are the matplotlib linestyles in this figure panel? Please format the output as a json as {"line styles":[]}, where each element of the list refers to the linestyle of each line in the figure panel in the form a matplotlib linestyle type.
#   Real A: ['-', ':', '-', '-', ':', '-', ':', '-']
# Claude A: {'line styles': ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-']}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the third row and third column panel. How many bars are there in the specified figure panel? Please format the output as a json as {"nbars":""} for this figure panel, where the "nbars" value should be an integer.
#   Real A: 40
# Claude A: {'nbars': 5}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the third row and left-most panel. How many lines are there in the specified figure panel? Please format the output as a json as {"nlines":""} for this figure panel, where the "nlines" value should be an integer.
#   Real A: 8
# Claude A: {'nlines': 8}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the top-left panel. How many scatter points are there in the specified figure panel? Please format the output as a json as {"npoints":""} for this figure panel, where the "npoints" value should be an integer.
#   Real A: 200
# Claude A: {'npoints': 'approximately 50'}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the third row and third column panel. What is the mean value of the data in this figure panel?  Please format the output as a json as {"mean x":""} for this figure panel, where the "mean x" value should be a float, calculated from the data values used to create the plot.
#   Real A: 2.4505763760244816
# Claude A: {'mean x': -2.0}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the top-left panel. What is the mean value of the data along the color-axis in this figure panel?  Please format the output as a json as {"mean color":""} for this figure panel, where the "mean color" value should be a float, calculated from the data values used to create the plot.
#   Real A: 16.59175357122436
# Claude A: {'mean color': 15.0}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the third row and left-most panel. What is the mean value of the data along the x-axis in this figure panel?  Please format the output as a json as {"mean x":"[]"} for this figure panel, where the "mean x" value should be a list of floats, calculated from the data values used to create the plot, where each element of the list corresponds to one line in the plot.
#   Real A: [2151.750567260352, 2236.779613685977, 2329.1224891225347, 2132.461388916928, 2200.6218137003143, 2244.9018676132027, 2300.890761998239, 2319.421749631111]
# Claude A: {'mean x': [2.5]}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the top-left panel. What is the mean value of the data along the y-axis in this figure panel?  Please format the output as a json as {"mean y":""} for this figure panel, where the "mean y" value should be a float, calculated from the data values used to create the plot.
#   Real A: 1215.4507634980612
# Claude A: {'mean y': 0.0}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the third row and third column panel. What is the median value of the data in this figure panel?  Please format the output as a json as {"median x":""} for this figure panel, where the "median x" value should be a float, calculated from the data values used to create the plot.
#   Real A: 2.3993031620846486
# Claude A: {'median x': -2.0}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the top-left panel. What is the median value of the data along the color-axis in this figure panel?  Please format the output as a json as {"median color":""} for this figure panel, where the "median color" value should be a float, calculated from the data values used to create the plot.
#   Real A: 17.16266827757063
# Claude A: {'median color': 15.0}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the third row and left-most panel. What is the median value of the data along the x-axis in this figure panel?  Please format the output as a json as {"median x":"[]"} for this figure panel, where the "median x" value should be a list of floats, calculated from the data values used to create the plot, where each element of the list corresponds to one line in the plot.
#   Real A: [2097.296055230158, 2247.815092023262, 2392.994521912118, 2012.8580721810085, 2222.3321955208885, 2256.161557803366, 2435.883526740812, 2360.432114616185]
# Claude A: {'median x': [2250.0]}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the top-left panel. What is the median value of the data along the y-axis in this figure panel?  Please format the output as a json as {"median y":""} for this figure panel, where the "median y" value should be a float, calculated from the data values used to create the plot.
#   Real A: -3276.9673778891047
# Claude A: {'median y': 0}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the third row and third column panel. Are there error bars on the data along the x-axis in this figure panel? Please format the output as a json as {"x-axis errors":""} where the value for the output is True (if error bars exist) or False (if error bars do not exist).
#   Real A: True
# Claude A: {'x-axis errors': 'False'}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the third row and third column panel. Are there error bars on the data along the y-axis in this figure panel? Please format the output as a json as {"y-axis errors":""} where the value for the output is True (if error bars exist) or False (if error bars do not exist).
#   Real A: False
# Claude A: {'y-axis errors': 'True'}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the third row and third column panel. What is the underlying distribution used to create the data in this figure panel? Please format the output as a json as {"distribution":""} for this figure panel, where the "distribution" value should be a string, calculated from the data values used to create the plot. Please choose the distribution from the following list: [random, linear, gaussian mixture model].
#   Real A: gaussian mixture model
# Claude A: {'distribution': 'gaussian mixture model'}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the top-left panel. What is the underlying distribution used to create the data in this figure panel along the color-axis? Please format the output as a json as {"distribution color":""} for this figure panel, where the "distribution color" value should be a string, calculated from the data values used to create the plot. Please choose the distribution from the following list: [random, linear, gaussian mixture model].
#   Real A: gaussian mixture model
# Claude A: {'distribution color': 'linear'}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the top-left panel. What is the underlying distribution used to create the data in this figure panel in the x/y-plane? Please format the output as a json as {"distribution x/y":""} for this figure panel, where the "distribution x/y" value should be a string, calculated from the data values used to create the plot. Please choose the distribution from the following list: [random, linear, gaussian mixture model].
#   Real A: gaussian mixture model
# Claude A: {'distribution x/y': 'gaussian mixture model'}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the third row and left-most panel. What is the functional relationship between the x and y values in this figure panel? Please format the output as a json as {"relationship":[]} where each element of the list corresponds to a single line in the figure.
#   Real A: ['random', 'random', 'random', 'random', 'random', 'random', 'random', 'random']
# Claude A: {'relationship': ['decreasing', 'decreasing', 'decreasing', 'decreasing', 'decreasing', 'decreasing', 'decreasing', 'decreasing', 'decreasing', 'decreasing', 'decreasing', 'decreasing', 'decreasing', 'decreasing', 'decreasing']}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the third row and left-most panel.Please choose each relationship for each line from the following list for each line: [random, linear, gaussian mixture model]. What is the functional relationship between the x and y values in this figure panel? Please format the output as a json as {"relationship":[]} where each element of the list corresponds to a single line in the figure.
#   Real A: ['random', 'random', 'random', 'random', 'random', 'random', 'random', 'random']
# Claude A: {'relationship': ['linear', 'linear', 'linear', 'linear', 'linear', 'linear', 'linear', 'linear', 'linear', 'linear', 'linear', 'linear', 'linear', 'linear', 'linear']}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the third row and left-most panel. Please note that there are a total of 8 lines in this plot, so the list should have a total of 8 entries. Please choose each relationship for each line from the following list for each line: [random, linear, gaussian mixture model]. What is the functional relationship between the x and y values in this figure panel? Please format the output as a json as {"relationship":[]} where each element of the list corresponds to a single line in the figure.
#   Real A: ['random', 'random', 'random', 'random', 'random', 'random', 'random', 'random']
# Claude A: {'relationship': ['linear', 'linear', 'linear', 'linear', 'linear', 'linear', 'linear', 'linear']}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the third row and left-most panel. Please note that there are a total of 8 lines in this plot, so the list should have a total of 8 entries.  What is the functional relationship between the x and y values in this figure panel? Please format the output as a json as {"relationship":[]} where each element of the list corresponds to a single line in the figure.
#   Real A: ['random', 'random', 'random', 'random', 'random', 'random', 'random', 'random']
# Claude A: {'relationship': ['decreasing', 'decreasing', 'decreasing', 'decreasing', 'decreasing', 'decreasing', 'decreasing', 'decreasing']}
