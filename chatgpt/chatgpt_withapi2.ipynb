# %% [markdown]
# ## ChatGPT
#
# Ask VQA to ChatGPT.

# %% [markdown]
# Docs:
#
# * how to upload images: https://platform.openai.com/docs/guides/vision
# * types of models: https://stackoverflow.com/questions/75774873/openai-api-error-this-is-a-chat-model-and-not-supported-in-the-v1-completions
# * token limits: https://platform.openai.com/settings/organization/limits
# * models: https://platform.openai.com/docs/models/model-endpoint-compatibility

# %%
#!pip install openai

# %%
# dir_api = '/Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api/' #store API results for example data
# #model = "gpt-5-nano-2025-08-07"
# model = "gpt-5.4-nano-2026-03-17"
# temperature = 1.0 ## only allowed
# verbosity = None # default
# reasoning_level = None # default


dir_api = '/Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/' #store API results for example data
model = "gpt-5.4-nano-2026-03-17"
temperature = 1.0 ## only allowed
verbosity = 'low' # default
reasoning_level = 'high' # default

# dir_api = '/Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose_mini/' #store API results for example data
# model = "gpt-5.4-mini-2026-03-17"
# temperature = 1.0 ## only allowed
# verbosity = 'low' # default
# reasoning_level = 'high' # default

key_file = '/Users/jnaiman/.openai/key.txt'

jsons_dir = '/Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/qa_jsons/' # directory where jsons created with figure are stored
imgs_dir = '/Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/' # where images are stored

# for saving temp images for reading in
tmp_dir = '/Users/jnaiman/Downloads/tmp/'

img_format = 'jpeg'

# for asking for reasoning
reasoning_text = 'In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.'

# %%
import openai
import base64
from openai import OpenAI
from PIL import Image
import numpy as np
import json
import re
import pickle
import os
from glob import glob

# debug
from importlib import reload

from sys import path
path.append('../')
import utils.llm_utils
reload(utils.llm_utils)
from utils.llm_utils import parse_qa, load_image, get_img_json_pair, parse_for_errors

from utils.plot_qa_utils import get_nplots
import time

# %%
# def send_to_chatgpt(question_list, client, image_path, encoded_image,
#                     model ="gpt-4o-mini", 
#                     tmp_dir = '/Users/jnaiman/Downloads/tmp/',
#                     test_run = True, fac=1.0, img_format='png',
#                     verbose=True, temperature=1.0,
#                     subset_questions_by_keys = None, reasoning = None, 
#                     reasoning_level=None, verbosity=None):
#     """
#     subset_questions_by_keys : only use a subset of questions to ping to model, e.g. ['median', 'how many gaussians']
#     """

#     iFac = 2.0 # just in case we want to progressively make the image smaller
#     success = False
#     is_subset = False
#     new_fac = fac
#     while not success:
#         try:
#         #if True:
#             # current question format is: ['persona', 'context','question', 'format'] (see readme in example_hists)
#             question = question_list['context'] + " " + question_list['question'] + " " + question_list['format']
#             if reasoning is not None:
#                 question += " " + reasoning
#             # lowercase the first word, just in case
#             question = question.lstrip() # no whitespace
#             question = question[0].lower() + question[1:]
#             if verbose: print('   on question:',question)
#             # Prepare the API request
#             prompt = f"I am going to show you an image. Now, {question}"
#             prompt_save = f"I am going to show you an image. Now, {question}"

#             if subset_questions_by_keys is not None and type(subset_questions_by_keys) == type([]): # make sure list
#                 for s in subset_questions_by_keys:
#                     if s in question:
#                         is_subset = True
#             else:
#                 is_subset = True
            

#             messages = [
#                 {"role": "developer", "content": question_list['persona']},
#                 {"role": "user", "content": [
#                     {
#                         "type": "input_text",
#                         "text": prompt
#                     },
#                     {
#                         "type": "input_image",
#                         "image_url": f"data:image/{img_format};base64,{encoded_image}"
#                     }
#                 ]}
#             ]
            

#             if not test_run and is_subset:
#                 # Build optional kwargs
#                 kwargs = {}
#                 if reasoning_level is not None:
#                     kwargs["reasoning"] = {"effort": reasoning_level}
#                 if verbosity is not None:
#                     kwargs["text"] = {"verbosity": verbosity}

#                 response = client.responses.create(
#                         model=model,
#                         input=messages,
#                         **kwargs
#                 )
#                 success = True
#             elif not is_subset:
#                 response = 'Not asked'
#                 success = True
#             else:
#                 success = True
#         except Exception as e:
#         #else:
#             print('[ERROR]', str(e))
#             new_fac = fac/iFac
#             print('new fac = ', new_fac)
#             encoded_image = load_image(image_path,fac=new_fac, tmp_dir=tmp_dir, img_format=img_format)
#             iFac += 1
    
#     if not test_run and is_subset:
#         # Get the response from the Responses API
#         answer = ""
#         for item in response.output:
#             if hasattr(item, "content") and item.content is not None:
#             #if hasattr(item, "content"):
#                 for block in item.content:
#                     if hasattr(block, "text"):
#                         answer += block.text

#         question_list['raw answer'] = answer
#         # format answer
#         answer_format = answer.replace("```json\n",'').replace("\n```",'')
#         try:
#             question_list['Response'] = json.loads(answer_format)
#         except:
#             question_list['Response'] = answer_format
#             question_list['Error'] = 'JSON formatting'
#         question_list['Response String'] = answer_format
#         success = True
#     elif not is_subset:
#         answer = response
#         question_list['raw answer'] = answer
#         question_list['Response'] = answer
#         question_list['Response String'] = answer
#         success = True
#     else:
#         question_list['Response'] = 'TEST RUN'
#         question_list['Response String'] = 'TEST RUN'
#     question_list['fac'] = new_fac

#     return question_list, prompt_save

# %%
def send_to_chatgpt(question_list, client, image_path, encoded_image,
                    model ="gpt-4o-mini", 
                    tmp_dir = '/Users/jnaiman/Downloads/tmp/',
                    test_run = True, fac=1.0, img_format='png',
                    verbose=True, temperature=1.0,
                    subset_questions_by_keys = None, reasoning = None, 
                    reasoning_level=None, verbosity=None,
                    max_retries=7):

    iFac = 2.0
    success = False
    is_subset = False
    new_fac = fac
    retry_count = 0

    while not success:
        try:
            question = question_list['context'] + " " + question_list['question'] + " " + question_list['format']
            if reasoning is not None:
                question += " " + reasoning
            question = question.lstrip()
            question = question[0].lower() + question[1:]
            if verbose: print('   on question:',question)
            prompt = f"I am going to show you an image. Now, {question}"
            prompt_save = f"I am going to show you an image. Now, {question}"

            if subset_questions_by_keys is not None and type(subset_questions_by_keys) == type([]):
                for s in subset_questions_by_keys:
                    if s in question:
                        is_subset = True
            else:
                is_subset = True

            messages = [
                {"role": "developer", "content": question_list['persona']},
                {"role": "user", "content": [
                    {
                        "type": "input_text",
                        "text": prompt
                    },
                    {
                        "type": "input_image",
                        "image_url": f"data:image/{img_format};base64,{encoded_image}"
                    }
                ]}
            ]

            if not test_run and is_subset:
                kwargs = {}
                if reasoning_level is not None:
                    kwargs["reasoning"] = {"effort": reasoning_level}
                if verbosity is not None:
                    kwargs["text"] = {"verbosity": verbosity}

                response = client.responses.create(
                    model=model,
                    input=messages,
                    **kwargs
                )
                success = True
            elif not is_subset:
                response = 'Not asked'
                success = True
            else:
                success = True

        except Exception as e:
            print('[ERROR]', e)
            error_str = str(e) # for later parsing

            if '429' in error_str:
                # rate limit — exponential backoff
                if retry_count >= max_retries:
                    print(f'Max retries ({max_retries}) reached on rate limit, giving up.')
                    raise
                wait_time = (2 ** retry_count) + 1  # 2, 3, 5, 9, 17 seconds
                print(f'Rate limit hit, waiting {wait_time}s before retry {retry_count+1}/{max_retries}...')
                time.sleep(wait_time)
                retry_count += 1
                # don't change the image size, just retry
            else:
                # other error (e.g. image too large) — resize and retry
                retry_count = 0  # reset backoff counter for non-rate-limit errors
                new_fac = fac/iFac
                print('new fac = ', new_fac)
                encoded_image = load_image(image_path, fac=new_fac, tmp_dir=tmp_dir, img_format=img_format)
                iFac += 1

    if not test_run and is_subset:
        answer = ""
        for item in response.output:
            if hasattr(item, "content") and item.content is not None:
                for block in item.content:
                    if hasattr(block, "text"):
                        answer += block.text

        question_list['raw answer'] = answer
        answer_format = answer.replace("```json\n",'').replace("\n```",'')
        try:
            question_list['Response'] = json.loads(answer_format)
        except:
            question_list['Response'] = answer_format
            question_list['Error'] = 'JSON formatting'
        question_list['Response String'] = answer_format
        success = True
    elif not is_subset:
        answer = response
        question_list['raw answer'] = answer
        question_list['Response'] = answer
        question_list['Response String'] = answer
        success = True
    else:
        question_list['Response'] = 'TEST RUN'
        question_list['Response String'] = 'TEST RUN'
    question_list['fac'] = new_fac

    return question_list, prompt_save

# %%
def print_qa(pickle_file, qa_in, subset_questions_by_keys=None, showNotAsked=False):
    if subset_questions_by_keys is not None:
        print('---------- ASKED ----------')
    print(pickle_file)
    print('*********')
    for qa_pairs in qa_in:
        hasSub = False
        if subset_questions_by_keys is not None and type(subset_questions_by_keys) == type([]):
            for s in subset_questions_by_keys:
                if s in qa_pairs['prompt']:
                    hasSub = True
        else:
            hasSub = True

        if hasSub:
            print('Prompt:', qa_pairs['prompt'])
            print('   Real A:', qa_pairs['A'])
            print('ChatGPT A:', qa_pairs['Response'])
            print('')

    if subset_questions_by_keys is not None and showNotAsked:
        print('')
        print('')
        print('------------ NOT ASKED -----------')
        for qa_pairs in qa_in:
            hasSub = False
            if subset_questions_by_keys is not None and type(subset_questions_by_keys) == type([]):
                for s in subset_questions_by_keys:
                    if s in qa_pairs['prompt']:
                        hasSub = True

            if not hasSub:
                print('Prompt:', qa_pairs['prompt'])
                print('   Real A:', qa_pairs['A'])
                print('ChatGPT A:', qa_pairs['Response'])
                print('')

# %%
# setup
with open(key_file,'r') as f:
    api_key = f.read()

client = OpenAI(
  api_key=api_key.strip(),  # this is also the default, it can be omitted
)

# %%
jsons_to_parse1 = glob(jsons_dir + '/*.json')
# clean
jsons_to_parse = []
for j in jsons_to_parse1:
    img_path = imgs_dir + j.split('/')[-1].removesuffix('_qa.json') + '.' + img_format
    if os.path.exists(img_path):
        jsons_to_parse.append(j)

print('total qa files:', len(jsons_to_parse))
jsons_to_parse[:3]
# Out:
# total qa files: 200
# ['/Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/qa_jsons/Picture_000015_qa.json',
#  '/Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/qa_jsons/Picture_000005_qa.json',
#  '/Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/qa_jsons/Picture_000077_qa.json']

# %% [markdown]
# Look at a possible questions:

# %%
iping = 0

while iping < len(jsons_to_parse):
    try:
        json_path = jsons_to_parse[iping]
        iping = len(jsons_to_parse)
    except:
        iping += 1
        print(iping)

if iping < len(jsons_to_parse):
    verbose = False
    restart = False

    fac = 1.0

    img_path = imgs_dir + json_path.split('/')[-1].removesuffix('_qa.json') + '.' + img_format
    encoded_image, img_format_media, base_json, err = get_img_json_pair(img_path, json_path, dir_api, 
                                                        fac=fac, restart=restart, img_format=img_format,
                                                        tmp_dir=tmp_dir)
    print('Image format media:', img_format_media)
else:
    base_json = {'VQA':'NOT FOUND'}

base_json['VQA']
# Out:
# 'NOT FOUND'

# %%
iMax = 211 # should be number of jsons
verbose = False
test_run = False # run w/o actually pinging openai
restart = False

subset_questions_by_keys = None # ['median', 'ngaussians'] # set to None to do all questions

reload(utils.llm_utils)
from utils.llm_utils import parse_qa

fac = 1.0
for ijson,json_path in enumerate(jsons_to_parse):
    if ijson >= iMax:
        continue

    print('on', ijson+1, 'of', min(iMax,len(jsons_to_parse)))

    # get image and base json
    img_path = imgs_dir + json_path.split('/')[-1].removesuffix('_qa.json') + '.' + img_format
    print('Processing image:', img_path)
    encoded_image, img_format_media, base_json, err = get_img_json_pair(img_path, json_path, dir_api, 
                                                      fac=fac, restart=restart,img_format=img_format,
                                                      tmp_dir=tmp_dir)

    if err:
        continue


    ###### create QA ########
    qa = []
    
    # figure-level
    for k,v in base_json['VQA']['Level 1']['Figure-level questions'].items():
        out = {'Q':v['Q'], 'A':v['A'], 'Level':'Level 1', 'type':'Figure-level questions', 'Response':"", 
               "persona":v['persona'], 'context':v['context'], 'question':v['question'], 'format':v['format'],
               "reasoning":reasoning_text}
        qa.append(out)
    for level in ['Level 2', 'Level 3']:
        if level in base_json['VQA']:
            if 'Figure-level questions' in base_json['VQA'][level]:
                #print('** yes, level ***', level)
                for k,v in base_json['VQA'][level]['Figure-level questions'].items():
                    out = {'Q':v['Q'], 'A':v['A'], 'Level':level, 'type':'Figure-level questions', 'Response':"", 
                        "persona":v['persona'], 'context':v['context'], 'question':v['question'], 'format':v['format'],
                        "reasoning":reasoning_text}
                    qa.append(out)
                #import sys; sys.exit()
    # what kinds?
    #types = ['(words + list)', '(words)']
    types = []
    
    # get uniques
    level_parse = 'Level 1'
    plot_level = 'Plot-level questions'
    qa = parse_qa(level_parse, plot_level, qa, base_json['VQA'], types, use_split_keys=False)
    
    level_parse = 'Level 2'
    plot_level = 'Plot-level questions'
    qa = parse_qa(level_parse, plot_level, qa, base_json['VQA'], types, use_split_keys=False)
    
    level_parse = 'Level 3'
    plot_level = 'Plot-level questions'
    qa = parse_qa(level_parse, plot_level, qa, base_json['VQA'], types, use_split_keys=False)

    responses = []
    for question_list in qa:
        response, prompt = send_to_chatgpt(question_list, client, img_path, encoded_image,
                    model = model, img_format = img_format_media, temperature=temperature,
                    test_run = test_run, subset_questions_by_keys=subset_questions_by_keys, 
                    fac=fac, reasoning = reasoning_text, reasoning_level=reasoning_level, verbosity=verbosity)
        responses.append(response)
        question_list['prompt'] = prompt

    # parse for errors
    qa = parse_for_errors(qa)

    # dump to file
    if not test_run:
        with open(dir_api + json_path.split('/')[-1].removesuffix('.json')+ '.pickle', 'wb') as ff:
            pickle.dump([qa, model], ff)
        print("just saved:", dir_api + json_path.split('/')[-1].removesuffix('.json')+ '.pickle')
    else:
        print('Would store at:', dir_api + json_path.split('/')[-1].removesuffix('.json')+ '.pickle')

print("!!!!!! DONE !!!!!!!")
# Out:
# on 1 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000015.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000015_qa.pickle
# on 2 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000005.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000005_qa.pickle
# on 3 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000077.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000077_qa.pickle
# on 4 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000067.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000067_qa.pickle
# on 5 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000152.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000152_qa.pickle
# on 6 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000142.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000142_qa.pickle
# on 7 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000093.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000093_qa.pickle
# on 8 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000083.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000083_qa.pickle
# on 9 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000189.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000189_qa.pickle
# on 10 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000199.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000199_qa.pickle
# on 11 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000130.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000130_qa.pickle
# on 12 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000048.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000048_qa.pickle
# on 13 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000120.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000120_qa.pickle
# on 14 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000058.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000058_qa.pickle
# on 15 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000116.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000116_qa.pickle
# on 16 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000106.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000106_qa.pickle
# on 17 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000174.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000174_qa.pickle
# on 18 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000164.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000164_qa.pickle
# on 19 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000190.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000190_qa.pickle
# on 20 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000180.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000180_qa.pickle
# on 21 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000129.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000129_qa.pickle
# on 22 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000051.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000051_qa.pickle
# on 23 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000139.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000139_qa.pickle
# on 24 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000041.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000041_qa.pickle
# on 25 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000033.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000033_qa.pickle
# on 26 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000023.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000023_qa.pickle
# on 27 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000107.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000107_qa.pickle
# on 28 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000117.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000117_qa.pickle
# on 29 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000165.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000165_qa.pickle
# on 30 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000175.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000175_qa.pickle
# on 31 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000040.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000040_qa.pickle
# on 32 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000138.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000138_qa.pickle
# on 33 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000050.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000050_qa.pickle
# on 34 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000128.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000128_qa.pickle
# on 35 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000181.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000181_qa.pickle
# on 36 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000191.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000191_qa.pickle
# on 37 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000022.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000022_qa.pickle
# on 38 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000032.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000032_qa.pickle
# on 39 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000004.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000004_qa.pickle
# on 40 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000014.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000014_qa.pickle
# on 41 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000066.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000066_qa.pickle
# on 42 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000076.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000076_qa.pickle
# on 43 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000082.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000082_qa.pickle
# on 44 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000092.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000092_qa.pickle
# on 45 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000143.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000143_qa.pickle
# on 46 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000153.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000153_qa.pickle
# on 47 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000059.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000059_qa.pickle
# on 48 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000121.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000121_qa.pickle
# on 49 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000049.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000049_qa.pickle
# on 50 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000131.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000131_qa.pickle
# on 51 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000198.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000198_qa.pickle
# on 52 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000188.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000188_qa.pickle
# on 53 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000177.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000177_qa.pickle
# on 54 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000167.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000167_qa.pickle
# on 55 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000115.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000115_qa.pickle
# on 56 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000105.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000105_qa.pickle
# on 57 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000089.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000089_qa.pickle
# on 58 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000099.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000099_qa.pickle
# on 59 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000030.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000030_qa.pickle
# on 60 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000148.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000148_qa.pickle
# on 61 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000020.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000020_qa.pickle
# on 62 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000158.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000158_qa.pickle
# on 63 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000052.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000052_qa.pickle
# on 64 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000042.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000042_qa.pickle
# on 65 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000193.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000193_qa.pickle
# on 66 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000183.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000183_qa.pickle
# on 67 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000074.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000074_qa.pickle
# on 68 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000064.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000064_qa.pickle
# on 69 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000016.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000016_qa.pickle
# on 70 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000006.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000006_qa.pickle
# on 71 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000133.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000133_qa.pickle
# on 72 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000123.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000123_qa.pickle
# on 73 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000090.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000090_qa.pickle
# on 74 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000080.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000080_qa.pickle
# on 75 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000029.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000029_qa.pickle
# on 76 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000151.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000151_qa.pickle
# on 77 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000039.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000039_qa.pickle
# on 78 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000141.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000141_qa.pickle
# on 79 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000065.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000065_qa.pickle
# on 80 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000075.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000075_qa.pickle
# on 81 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000007.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000007_qa.pickle
# on 82 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000017.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000017_qa.pickle
# on 83 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000122.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000122_qa.pickle
# on 84 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000132.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000132_qa.pickle
# on 85 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000140.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000140_qa.pickle
# on 86 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000038.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000038_qa.pickle
# on 87 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000150.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000150_qa.pickle
# on 88 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000028.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000028_qa.pickle
# on 89 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000081.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000081_qa.pickle
# on 90 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000091.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000091_qa.pickle
# on 91 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000200.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000200_qa.pickle
# on 92 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000166.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000166_qa.pickle
# on 93 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000176.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000176_qa.pickle
# on 94 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000104.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000104_qa.pickle
# on 95 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000114.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000114_qa.pickle
# on 96 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000159.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000159_qa.pickle
# on 97 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000021.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000021_qa.pickle
# on 98 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000149.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000149_qa.pickle
# on 99 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000031.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000031_qa.pickle
# on 100 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000098.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000098_qa.pickle
# on 101 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000088.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000088_qa.pickle
# on 102 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000182.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000182_qa.pickle
# on 103 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000192.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000192_qa.pickle
# on 104 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000043.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000043_qa.pickle
# on 105 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000053.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000053_qa.pickle
# on 106 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000034.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000034_qa.pickle
# on 107 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000024.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000024_qa.pickle
# on 108 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000197.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000197_qa.pickle
# on 109 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000187.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000187_qa.pickle
# on 110 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000056.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000056_qa.pickle
# on 111 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000046.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000046_qa.pickle
# on 112 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000173.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000173_qa.pickle
# on 113 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000163.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000163_qa.pickle
# on 114 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000111.jpeg
# have file already: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000111_qa.pickle
# on 115 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000069.jpeg
#    on question: how many panels are in this figure? Please format the output as a json as {"nrows":"", "ncols":""} to store the number of rows and columns. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: assume this is a figure made with matplotlib in Python.  Examples of plotting styles are "classic" or "ggplot". Examples of plotting styles are "classic" or "ggplot". What is the plot style used in this figure? Please format the output as a json as {"plot style":""} to store the matplotlib plotting style used in the figure. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: assume this is a figure made with matplotlib in Python. Examples of matplotlib colormaps are "rainbow" or "Reds". What is the colormap that was used in this figure? Please format the output as a json as {"colormap":""} to store the matplotlib colormap used in the figure. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: what is the aspect ratio of this figure? Please format the output as a json as {"aspect ratio":""} to store the aspect ratio of the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: what are the titles for each figure panel? Please format the output as a json as {"titles":[]}, where the list is a list of strings of all of the titles. If there is a single plot, this should be one element in this list, and if there are multiple plots the list should be in row-major (C-style) order. If a plot does not have a title, then denote this by an empty string in the list.  Please format any formulas in the title in a Python LaTeX string (for example 'Light $\\alpha$').  In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: what are the x-axis titles for each figure panel? Please format the output as a json as {"xlabels":[]}, where the list is a list of strings of all of the x-axis titles. If there is a single plot, this should be one element in this list, and if there are multiple plots the list should be in row-major (C-style) order. If a plot does not have an x-axis title, then denote this by an empty string in the list.  Please format any formulas in the title in a Python LaTeX string (for example 'Light $\\alpha$').  In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: what are the y-axis titles for each figure panel? Please format the output as a json as {"ylabels":[]}, where the list is a list of strings of all of the y-axis titles. If there is a single plot, this should be one element in this list, and if there are multiple plots the list should be in row-major (C-style) order. If a plot does not have an y-axis title, then denote this by an empty string in the list.  Please format any formulas in the title in a Python LaTeX string (for example 'Light $\\alpha$').  In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: what are the values for each of the tick marks on the x-axis? Please format the output as a json as {"xtick values":[[]]}, where each element of the outer list refers to a single panel, and each inner list is a list of the x-axis tick mark values. If there is a single plot, this should be one element in the outer list, and if there are multiple plots the outer list should be in row-major (C-style) order. If a plot does not have any x-axis tick values, then denote this by an empty string in the inner list.  Please format any formulas in the x-axis tick values in a Python LaTeX string (for example 'Light $\\alpha$'). In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: what are the values for each of the tick marks on the y-axis? Please format the output as a json as {"ytick values":[[]]}, where each element of the outer list refers to a single panel, and each inner list is a list of the y-axis tick mark values. If there is a single plot, this should be one element in the outer list, and if there are multiple plots the outer list should be in row-major (C-style) order. If a plot does not have any y-axis tick values, then denote this by an empty string in the inner list.  Please format any formulas in the y-axis tick values in a Python LaTeX string (for example 'Light $\\alpha$'). In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: please choose each plot type from the following list: [contour, histogram, line, scatter]. What are the plot types for each panel in the figure? Please format the output as a json as {"plot types":[]}, where each element of the list refers to the plot type of a single panel. If there is a single plot, this should be one element in this list, and if there are multiple plots the list should be in row-major (C-style) order.  In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: what are the plot types for each panel in the figure? Please format the output as a json as {"plot types":[]}, where each element of the list refers to the plot type of a single panel. If there is a single plot, this should be one element in this list, and if there are multiple plots the list should be in row-major (C-style) order.  In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: how many scatter points are there in the specified figure panel? Please format the output as a json as {"npoints":""} for this figure panel, where the "npoints" value should be an integer. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: what is the maximum value of the data along the color-axis in this figure panel?  Please format the output as a json as {"maximum color":""} for this figure panel, where the "maximum color" value should be a float, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: what is the maximum value of the data along the x-axis in this figure panel?  Please format the output as a json as {"maximum x":""} for this figure panel, where the "maximum x" value should be a float, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: what is the maximum value of the data along the y-axis in this figure panel?  Please format the output as a json as {"maximum y":""} for this figure panel, where the "maximum y" value should be a float, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: what is the mean value of the data along the color-axis in this figure panel?  Please format the output as a json as {"mean color":""} for this figure panel, where the "mean color" value should be a float, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: what is the mean value of the data along the x-axis in this figure panel?  Please format the output as a json as {"mean x":""} for this figure panel, where the "mean x" value should be a float, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: what is the mean value of the data along the y-axis in this figure panel?  Please format the output as a json as {"mean y":""} for this figure panel, where the "mean y" value should be a float, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: what is the median value of the data along the color-axis in this figure panel?  Please format the output as a json as {"median color":""} for this figure panel, where the "median color" value should be a float, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: what is the median value of the data along the x-axis in this figure panel?  Please format the output as a json as {"median x":""} for this figure panel, where the "median x" value should be a float, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: what is the median value of the data along the y-axis in this figure panel?  Please format the output as a json as {"median y":""} for this figure panel, where the "median y" value should be a float, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: what is the minimum value of the data along the color-axis in this figure panel?  Please format the output as a json as {"minimum color":""} for this figure panel, where the "minimum color" value should be a float, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: what is the minimum value of the data along the x-axis in this figure panel?  Please format the output as a json as {"minimum x":""} for this figure panel, where the "minimum x" value should be a float, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: what is the minimum value of the data along the y-axis in this figure panel?  Please format the output as a json as {"minimum y":""} for this figure panel, where the "minimum y" value should be a float, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: are there error bars on the data along the x-axis in this figure panel? Please format the output as a json as {"x-axis errors":""} where the value for the output is True (if error bars exist) or False (if error bars do not exist). In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: are there error bars on the data along the y-axis in this figure panel? Please format the output as a json as {"y-axis errors":""} where the value for the output is True (if error bars exist) or False (if error bars do not exist). In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: please choose the distribution from the following list: [random, linear, gaussian mixture model]. What is the underlying distribution used to create the data in this figure panel along the color-axis? Please format the output as a json as {"distribution color":""} for this figure panel, where the "distribution color" value should be a string, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: please choose the distribution from the following list: [random, linear, gaussian mixture model]. What is the underlying distribution used to create the data in this figure panel in the x/y-plane? Please format the output as a json as {"distribution x/y":""} for this figure panel, where the "distribution x/y" value should be a string, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
# just saved: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000069_qa.pickle
# on 116 of 200
# Processing image: /Users/jnaiman/Dropbox/jcdl_followup/synthetic_figures/imgs/Picture_000101.jpeg
#    on question: how many panels are in this figure? Please format the output as a json as {"nrows":"", "ncols":""} to store the number of rows and columns. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: assume this is a figure made with matplotlib in Python.  Examples of plotting styles are "classic" or "ggplot". Examples of plotting styles are "classic" or "ggplot". What is the plot style used in this figure? Please format the output as a json as {"plot style":""} to store the matplotlib plotting style used in the figure. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: assume this is a figure made with matplotlib in Python. Examples of matplotlib colormaps are "rainbow" or "Reds". What is the colormap that was used in this figure? Please format the output as a json as {"colormap":""} to store the matplotlib colormap used in the figure. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: what is the aspect ratio of this figure? Please format the output as a json as {"aspect ratio":""} to store the aspect ratio of the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: what are the titles for each figure panel? Please format the output as a json as {"titles":[]}, where the list is a list of strings of all of the titles. If there is a single plot, this should be one element in this list, and if there are multiple plots the list should be in row-major (C-style) order. If a plot does not have a title, then denote this by an empty string in the list.  Please format any formulas in the title in a Python LaTeX string (for example 'Light $\\alpha$').  In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: what are the x-axis titles for each figure panel? Please format the output as a json as {"xlabels":[]}, where the list is a list of strings of all of the x-axis titles. If there is a single plot, this should be one element in this list, and if there are multiple plots the list should be in row-major (C-style) order. If a plot does not have an x-axis title, then denote this by an empty string in the list.  Please format any formulas in the title in a Python LaTeX string (for example 'Light $\\alpha$').  In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
# ...
#    on question: the following question refers to the plot in the top-left panel. What is the style of the contour plot? Please choose the style from the following list: [image, contour lines, both]. Please format the output as a json as {"image or lines":""} for this figure panel, where the "image or lines" value should be a string. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: the following question refers to the plot in the top row and fourth from the left panel. Please choose each linestyle from the following list: [-, --, :]. What are the matplotlib linestyles in this figure panel? Please format the output as a json as {"line styles":[]}, where each element of the list refers to the linestyle of each line in the figure panel in the form a matplotlib linestyle type. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: the following question refers to the plot in the top row and fourth from the left panel. How many lines are there in the specified figure panel? Please format the output as a json as {"nlines":""} for this figure panel, where the "nlines" value should be an integer. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: the following question refers to the plot in the top-left panel. What is the maximum value of the data along the color-axis in this figure panel?  Please format the output as a json as {"maximum color":""} for this figure panel, where the "maximum color" value should be a float, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: the following question refers to the plot in the top row and fourth from the left panel. What is the maximum value of the data along the x-axis in this figure panel?  Please format the output as a json as {"maximum x":"[]"} for this figure panel, where the "maximum x" value should be a list of floats, calculated from the data values used to create the plot, where each element of the list corresponds to one line in the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: the following question refers to the plot in the top-left panel. What is the maximum value of the data along the y-axis in this figure panel?  Please format the output as a json as {"maximum y":""} for this figure panel, where the "maximum y" value should be a float, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: the following question refers to the plot in the top-left panel. What is the mean value of the data along the color-axis in this figure panel?  Please format the output as a json as {"mean color":""} for this figure panel, where the "mean color" value should be a float, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: the following question refers to the plot in the top row and fourth from the left panel. What is the mean value of the data along the x-axis in this figure panel?  Please format the output as a json as {"mean x":"[]"} for this figure panel, where the "mean x" value should be a list of floats, calculated from the data values used to create the plot, where each element of the list corresponds to one line in the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: the following question refers to the plot in the top-left panel. What is the mean value of the data along the y-axis in this figure panel?  Please format the output as a json as {"mean y":""} for this figure panel, where the "mean y" value should be a float, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: the following question refers to the plot in the top-left panel. What is the median value of the data along the color-axis in this figure panel?  Please format the output as a json as {"median color":""} for this figure panel, where the "median color" value should be a float, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: the following question refers to the plot in the top row and fourth from the left panel. What is the median value of the data along the x-axis in this figure panel?  Please format the output as a json as {"median x":"[]"} for this figure panel, where the "median x" value should be a list of floats, calculated from the data values used to create the plot, where each element of the list corresponds to one line in the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: the following question refers to the plot in the top-left panel. What is the median value of the data along the y-axis in this figure panel?  Please format the output as a json as {"median y":""} for this figure panel, where the "median y" value should be a float, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: the following question refers to the plot in the top-left panel. What is the minimum value of the data along the color-axis in this figure panel?  Please format the output as a json as {"minimum color":""} for this figure panel, where the "minimum color" value should be a float, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: the following question refers to the plot in the top row and fourth from the left panel. What is the minimum value of the data along the x-axis in this figure panel?  Please format the output as a json as {"minimum x":"[]"} for this figure panel, where the "minimum x" value should be a list of floats, calculated from the data values used to create the plot, where each element of the list corresponds to one line in the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: the following question refers to the plot in the top-left panel. What is the minimum value of the data along the y-axis in this figure panel?  Please format the output as a json as {"minimum y":""} for this figure panel, where the "minimum y" value should be a float, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: the following question refers to the plot in the top row and fourth from the left panel. Are there error bars on the data along the x-axis in this figure panel? Please format the output as a json as {"x-axis errors":""} where the value for the output is True (if error bars exist) or False (if error bars do not exist). In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: the following question refers to the plot in the top row and fourth from the left panel. Are there error bars on the data along the y-axis in this figure panel? Please format the output as a json as {"y-axis errors":""} where the value for the output is True (if error bars exist) or False (if error bars do not exist). In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: the following question refers to the plot in the top-left panel. Please choose the distribution from the following list: [random, linear, gaussian mixture model]. What is the underlying distribution used to create the data in this figure panel along the color-axis? Please format the output as a json as {"distribution color":""} for this figure panel, where the "distribution color" value should be a string, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: the following question refers to the plot in the top-left panel. Please choose the distribution from the following list: [random, linear, gaussian mixture model]. What is the underlying distribution used to create the data in this figure panel in the x/y-plane? Please format the output as a json as {"distribution x/y":""} for this figure panel, where the "distribution x/y" value should be a string, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: the following question refers to the plot in the top row and fourth from the left panel. What is the functional relationship between the x and y values in this figure panel? Please format the output as a json as {"relationship":[]} where each element of the list corresponds to a single line in the figure. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: the following question refers to the plot in the top row and fourth from the left panel. Please choose each relationship for each line from the following list for each line: [random, linear, gaussian mixture model]. What is the functional relationship between the x and y values in this figure panel? Please format the output as a json as {"relationship":[]} where each element of the list corresponds to a single line in the figure. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: the following question refers to the plot in the top row and fourth from the left panel. Please note that there are a total of 1 lines in this plot, so the list should have a total of 1 entries.  Please choose each relationship for each line from the following list for each line: [random, linear, gaussian mixture model]. What is the functional relationship between the x and y values in this figure panel? Please format the output as a json as {"relationship":[]} where each element of the list corresponds to a single line in the figure. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    on question: the following question refers to the plot in the top row and fourth from the left panel. Please note that there are a total of 1 lines in this plot, so the list should have a total of 1 entries.  What is the functional relationship between the x and y values in this figure panel? Please format the output as a json as {"relationship":[]} where each element of the list corresponds to a single line in the figure. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
# just saved: /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000072_qa.pickle
# !!!!!! DONE !!!!!!!

# %%
#(3.89-3.56)*200/10

# %% [markdown]
# ## Look at data
#
# Check out one, if you wanna:

# %%
pickles = glob(dir_api + '*_qa.pickle')
pickles[:5]
# Out:
# ['/Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000193_qa.pickle',
#  '/Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000066_qa.pickle',
#  '/Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000120_qa.pickle',
#  '/Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000134_qa.pickle',
#  '/Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000072_qa.pickle']

# %%
ifile = 5
with open(pickles[ifile], 'rb') as f:
    qa_in = pickle.load(f)[0]

# %%
print_qa(pickles[ifile], qa_in, subset_questions_by_keys=subset_questions_by_keys, showNotAsked=False)
# Out:
# /Users/jnaiman/Dropbox/jcdl_followup/LMM_outputs/chatgpt_api_highR_lowVerbose/Picture_000008_qa.pickle
# *********
# Prompt: I am going to show you an image. Now, how many panels are in this figure? Please format the output as a json as {"nrows":"", "ncols":""} to store the number of rows and columns. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: {'nrows': 3, 'ncols': 1}
# ChatGPT A: {"nrows":"3","ncols":"1"}
# {"explanation":"The figure contains three vertically stacked subplots (top, middle, and bottom), each spanning the full width, with no side-by-side panels. Therefore it has 3 rows and 1 column."}
#
# Prompt: I am going to show you an image. Now, assume this is a figure made with matplotlib in Python.  Examples of plotting styles are "classic" or "ggplot". Examples of plotting styles are "classic" or "ggplot". What is the plot style used in this figure? Please format the output as a json as {"plot style":""} to store the matplotlib plotting style used in the figure. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: {'plot style': '_classic_test_patch'}
# ChatGPT A: {"plot style":"ggplot"}
# {"explanation":"The figure uses a light gray axes/background with visible white gridlines, which matches Matplotlib’s 'ggplot' style. The 'classic' style typically has a white background with no such gray/white-grid theme."}
#
# Prompt: I am going to show you an image. Now, assume this is a figure made with matplotlib in Python. Examples of matplotlib colormaps are "rainbow" or "Reds". What is the colormap that was used in this figure? Please format the output as a json as {"colormap":""} to store the matplotlib colormap used in the figure. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: {'colormap': 'plasma_r'}
# ChatGPT A: {"colormap":"RdYlGn"}
#
# {"explanation":"The figure uses colors that transition between a red/orange end and a green end, with little/no blue and no single-hue-only behavior. This red–yellow–green style matches matplotlib’s diverging colormap \"RdYlGn\" (red/orange on one side and green on the other), whereas common alternatives like \"viridis\" (purple→green→yellow) or \"Greens\" (single-hue) do not account for the orange/red series seen in the top panel."}
#
# Prompt: I am going to show you an image. Now, what is the aspect ratio of this figure? Please format the output as a json as {"aspect ratio":""} to store the aspect ratio of the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: {'aspect ratio': 0.466656895064835}
# ChatGPT A: {"aspect ratio":"3:8"}
# {"explanation":"The figure is clearly portrait-oriented: its height is a little over 2.5 times its width. Estimating width/height gives about 0.375, i.e., an aspect ratio of approximately 3:8 (width:height)."}
#
# Prompt: I am going to show you an image. Now, what are the titles for each figure panel? Please format the output as a json as {"titles":[]}, where the list is a list of strings of all of the titles. If there is a single plot, this should be one element in this list, and if there are multiple plots the list should be in row-major (C-style) order. If a plot does not have a title, then denote this by an empty string in the list.  Please format any formulas in the title in a Python LaTeX string (for example 'Light $\\alpha$').  In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: {'titles': ['', '', '']}
# ChatGPT A: {"titles":["","",""]}
# {"explanation":"The figure contains three stacked subplots. I do not see any distinct title text above any subplot (only axis labels such as “VLA”, “theoretical layers”, “Structures”, and “PANELS: ORDERX TEST”). Therefore, each panel’s title is empty."}
#
# Prompt: I am going to show you an image. Now, what are the x-axis titles for each figure panel? Please format the output as a json as {"xlabels":[]}, where the list is a list of strings of all of the x-axis titles. If there is a single plot, this should be one element in this list, and if there are multiple plots the list should be in row-major (C-style) order. If a plot does not have an x-axis title, then denote this by an empty string in the list.  Please format any formulas in the title in a Python LaTeX string (for example 'Light $\\alpha$').  In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: {'xlabels': ['VLA', '$\\sigma_e$  Volume', 'Approaches']}
# ChatGPT A: {"xlabels":["VLA","$\\sigma_{F}$ Volume $\\times 10^{4}$",""]}
#
# {"explanation":"The image shows three stacked figure panels. The top panel has the x-axis title \"VLA\". The middle panel’s x-axis label reads \"$\\sigma_{F}$ Volume\" with a scaling factor \"× 10^{4}\". The bottom panel has x tick marks but no visible x-axis title, so it is recorded as an empty string."}
#
# Prompt: I am going to show you an image. Now, what are the y-axis titles for each figure panel? Please format the output as a json as {"ylabels":[]}, where the list is a list of strings of all of the y-axis titles. If there is a single plot, this should be one element in this list, and if there are multiple plots the list should be in row-major (C-style) order. If a plot does not have an y-axis title, then denote this by an empty string in the list.  Please format any formulas in the title in a Python LaTeX string (for example 'Light $\\alpha$').  In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: {'ylabels': ['theories layers', 'Structures', 'PANELS ORDER TEST']}
# ChatGPT A: {"ylabels":["Theoretical Layers","Structures","PANELS - ORDER TEST"]}
# {"explanation":"The image shows three vertically stacked panels. Reading the left-side y-axis titles in each panel: the top panel is labeled \"Theoretical Layers\", the middle panel is labeled \"Structures\", and the bottom panel is labeled \"PANELS - ORDER TEST\"."}
#
# Prompt: I am going to show you an image. Now, what are the values for each of the tick marks on the x-axis? Please format the output as a json as {"xtick values":[[]]}, where each element of the outer list refers to a single panel, and each inner list is a list of the x-axis tick mark values. If there is a single plot, this should be one element in the outer list, and if there are multiple plots the outer list should be in row-major (C-style) order. If a plot does not have any x-axis tick values, then denote this by an empty string in the inner list.  Please format any formulas in the x-axis tick values in a Python LaTeX string (for example 'Light $\\alpha$'). In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: {'xtick values': [['$\\mathdefault{5}$', '$\\mathdefault{10}$', '$\\mathdefault{15}$', '$\\mathdefault{20}$', '$\\mathdefault{25}$', '$\\mathdefault{30}$'], ['$\\mathdefault{−8}$', '$\\mathdefault{−7}$', '$\\mathdefault{−6}$', '$\\mathdefault{−5}$', '$\\mathdefault{−4}$', '$\\mathdefault{−3}$', '$\\mathdefault{−2}$'], ['$\\mathdefault{50}$', '$\\mathdefault{75}$', '$\\mathdefault{100}$', '$\\mathdefault{125}$', '$\\mathdefault{150}$', '$\\mathdefault{175}$', '$\\mathdefault{200}$']]}
# ChatGPT A: {"xtick values":[[5,10,15,20,25,30],[-8,-7,-6,-5,-4,-3,-2],[50,75,100,125,150,175,200]]}
# {"explanation":"The image shows 3 vertically stacked panels. For each panel, I read the numeric x-axis tick labels left-to-right: (1) top panel (VLA) shows ticks at 5, 10, 15, 20, 25, 30; (2) middle panel (σ_f Volume ×10^4) shows ticks at -8, -7, -6, -5, -4, -3, -2; (3) bottom panel shows ticks at 50, 75, 100, 125, 150, 175, 200."}
#
# Prompt: I am going to show you an image. Now, what are the values for each of the tick marks on the y-axis? Please format the output as a json as {"ytick values":[[]]}, where each element of the outer list refers to a single panel, and each inner list is a list of the y-axis tick mark values. If there is a single plot, this should be one element in the outer list, and if there are multiple plots the outer list should be in row-major (C-style) order. If a plot does not have any y-axis tick values, then denote this by an empty string in the inner list.  Please format any formulas in the y-axis tick values in a Python LaTeX string (for example 'Light $\\alpha$'). In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: {'ytick values': [['$\\mathdefault{−3}$', '$\\mathdefault{−2}$', '$\\mathdefault{−1}$', '$\\mathdefault{0}$', '$\\mathdefault{1}$'], ['$\\mathdefault{0}$', '$\\mathdefault{10}$', '$\\mathdefault{20}$', '$\\mathdefault{30}$', '$\\mathdefault{40}$', '$\\mathdefault{50}$'], ['$\\mathdefault{0}$', '$\\mathdefault{50}$', '$\\mathdefault{100}$', '$\\mathdefault{150}$', '$\\mathdefault{200}$', '$\\mathdefault{250}$', '$\\mathdefault{300}$']]}
# ChatGPT A: {"ytick values":[[ "1","0","-1","-2","-3" ],[ "0","10","20","30","40","50" ],[ "0","50","100","150","200","250","300" ]]}
# {"explanation":"The image shows three vertically stacked subplots. I read the numeric labels next to each horizontal gridline on the y-axis for each subplot: (1) theoretical layers: 1, 0, -1, -2, -3; (2) Structures: 0, 10, 20, 30, 40, 50; (3) PANELS/ORFINDER TESTS: 0, 50, 100, 150, 200, 250, 300."}
#
# Prompt: I am going to show you an image. Now, please choose each plot type from the following list: [contour, histogram, line, scatter]. What are the plot types for each panel in the figure? Please format the output as a json as {"plot types":[]}, where each element of the list refers to the plot type of a single panel. If there is a single plot, this should be one element in this list, and if there are multiple plots the list should be in row-major (C-style) order.  In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: {'plot types': ['line', 'histogram', 'histogram']}
# ChatGPT A: {"plot types":["scatter","histogram","histogram"]}
# {"explanation":"The figure has three vertically stacked panels. Panel 1 shows individual data points/markers at discrete x positions without a filled adjacent distribution, indicating a scatter plot. Panel 2 shows vertical bars representing counts/values across bins on the x-axis (bar-style distribution), closest to a histogram among the given options. Panel 3 similarly shows many vertical bars across the x-range with no connecting line, indicating a histogram."}
#
# Prompt: I am going to show you an image. Now, what are the plot types for each panel in the figure? Please format the output as a json as {"plot types":[]}, where each element of the list refers to the plot type of a single panel. If there is a single plot, this should be one element in this list, and if there are multiple plots the list should be in row-major (C-style) order.  In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: {'plot types': ['line', 'histogram', 'histogram']}
# ChatGPT A: {"plot types":["bar chart","box plot","histogram"]}
# {"explanation":"The figure has three vertically stacked panels. Panel 1 shows discrete vertical bars at different VLA values (two colored series), indicating a bar chart. Panel 2 shows repeated rectangular boxes with vertical whiskers for binned x-values, characteristic of box-and-whisker (box) plots. Panel 3 shows many adjacent thin vertical bars forming a distribution over the x-axis, corresponding to a histogram (or bar-based frequency distribution)."}
#
# Prompt: I am going to show you an image. Now, assume the following indexing for the panels in this figure: plot 0 is the top-left panel, plot 1 is the second row and left-most panel, plot 2 is the third row and left-most panel. Which plot shows the largest median data values? Please choose from the following list of plot numbers: [1, 2]. Please format the output as a json as {"cross - largest median":""} for this figure panel, where the "cross - largest median" value should be an integer referring to the panel number which shows the largest data median. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: {'cross - largest median (list)': 2}
# ChatGPT A: {"cross - largest median":2}
# {"explanation":"Among the candidate panels, plot 2 (bottom) has a much higher central tendency: its median values cluster around the ~200–260 range on the y-axis, whereas plot 1 (middle) clusters around roughly ~40–55. Therefore, plot 2 has the largest median."}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the top-left panel. Please choose each linestyle from the following list: [-, --, :]. What are the matplotlib linestyles in this figure panel? Please format the output as a json as {"line styles":[]}, where each element of the list refers to the linestyle of each line in the figure panel in the form a matplotlib linestyle type. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: [':', '-']
# ChatGPT A: {"line styles":["-","--"]}
#
# {"explanation":"In the top-left panel, one set of plotted lines (teal) is continuous with no gaps, matching matplotlib linestyle '-' . The other set (orange) is rendered with clear repeating dash gaps, matching matplotlib linestyle '--' . No lines in the panel appear dotted (':')."}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the third row and left-most panel. How many bars are there in the specified figure panel? Please format the output as a json as {"nbars":""} for this figure panel, where the "nbars" value should be an integer. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: 28
# ChatGPT A: {"nbars":150}
# {"explanation":"In the bottom (3rd row, left-most) panel, the bar chart spans the x-range from 50 to 200. The bars are drawn at 1-unit increments across this full range, so the number of bars equals 200 − 50 = 150."}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the top-left panel. How many lines are there in the specified figure panel? Please format the output as a json as {"nlines":""} for this figure panel, where the "nlines" value should be an integer. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: 2
# ChatGPT A: {"nlines":2}
# {"explanation":"In the top-left panel, there are two distinct line series visible: one set of solid teal vertical lines and one set of orange dashed vertical lines."}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the third row and left-most panel. What is the maximum value of the data in this figure panel?  Please format the output as a json as {"maximum x":""} for this figure panel, where the "maximum x" value should be a float, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: 199.81953053813277
# ChatGPT A: {"maximum x":300.0}
#
# {"explanation":"In the third-row, left-most (bottom) panel, the y-axis is labeled up to 300. The tallest bar reaches the 300 tick mark (no bar extends above it), so the maximum data value shown is 300.0."}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the top-left panel. What is the maximum value of the data along the x-axis in this figure panel?  Please format the output as a json as {"maximum x":"[]"} for this figure panel, where the "maximum x" value should be a list of floats, calculated from the data values used to create the plot, where each element of the list corresponds to one line in the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: [30.726630440845106, 31.094599385530866]
# ChatGPT A: {"maximum x":[30.0,30.0]}
#
# {"explanation":"In the top-left panel, the x-axis (“VLA”) is labeled with ticks ending at 30. The rightmost plotted points/bars for both visible line series (teal and orange) occur at the tick position x = 30, so the maximum x-value for each line is 30.0."}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the third row and left-most panel. What is the mean value of the data in this figure panel?  Please format the output as a json as {"mean x":""} for this figure panel, where the "mean x" value should be a float, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: 119.98585832284165
# ChatGPT A: {"mean x":250.0}
#
# {"explanation":"The bottom (third-row, left-most) panel shows many bar heights clustered around the 250 tick mark on the y-axis (PANETS ORDER TESTS). Averaging the plotted bar values (using the bar-top values read from the chart) gives a mean of approximately 250.0."}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the top-left panel. What is the mean value of the data along the x-axis in this figure panel?  Please format the output as a json as {"mean x":"[]"} for this figure panel, where the "mean x" value should be a list of floats, calculated from the data values used to create the plot, where each element of the list corresponds to one line in the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: [17.548598654723804, 19.060864920192174]
# ChatGPT A: {"mean x":[17.5,17.5]}
#
# {"explanation":"In the top-left panel there are two plotted lines (teal solid and orange dashed). Each line uses the same VLA x-values at 5, 10, 15, 20, 25, and 30. The mean x for each line is (5+10+15+20+25+30)/6 = 17.5."}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the third row and left-most panel. What is the median value of the data in this figure panel?  Please format the output as a json as {"median x":""} for this figure panel, where the "median x" value should be a float, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: 120.30321301100406
# ChatGPT A: {"median x":260.0}
# {"explanation":"In the third-row, left-most panel (bottom plot), the central tendency of the bars/boxes clusters around the y-value near the 260 mark on the labeled y-axis (between 250 and 300). Reading the middle of the distribution from the figure gives a median of approximately 260.0."}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the top-left panel. What is the median value of the data along the x-axis in this figure panel?  Please format the output as a json as {"median x":"[]"} for this figure panel, where the "median x" value should be a list of floats, calculated from the data values used to create the plot, where each element of the list corresponds to one line in the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: [19.830698949268616, 21.180689851628703]
# ChatGPT A: {"median x":[17.5,17.5]}
# {"explanation":"In the top-left panel, the x-axis (“VLA”) takes values at the major tick marks 5, 10, 15, 20, 25, and 30 for the plotted series (teal solid and orange dashed). For each line, the median x-value is therefore the median of these six x positions: median = (15 + 20) / 2 = 17.5. Since both plotted lines use the same x-values, the median x is 17.5 for each line."}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the third row and left-most panel. What is the minimum value of the data in this figure panel?  Please format the output as a json as {"minimum x":""} for this figure panel, where the "minimum x" value should be a float, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: 44.92069548014373
# ChatGPT A: {"minimum x":20.0}
# {"explanation":"In the third-row left-most (bottom) panel, the data are shown as vertical bars with their tops indicating the values. The shortest bar on the right edge reaches slightly above the 0 baseline but well below the 50 gridline; reading from the bar heights on the y-axis, the minimum value is approximately 20.0."}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the top-left panel. What is the minimum value of the data along the x-axis in this figure panel?  Please format the output as a json as {"minimum x":"[]"} for this figure panel, where the "minimum x" value should be a list of floats, calculated from the data values used to create the plot, where each element of the list corresponds to one line in the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: [4.666436370694444, 4.352061377036732]
# ChatGPT A: {"minimum x":[5.0,5.0]}
# {"explanation":"In the top-left panel (x-axis labeled VLA), the leftmost plotted data points for both visible series (green solid and orange dashed) occur at the first x tick/gridline, labeled 5.0. No plotted values appear to the left of x=5 in that panel, so the minimum x value for each line is 5.0."}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the third row and left-most panel. Are there error bars on the data along the x-axis in this figure panel? Please format the output as a json as {"x-axis errors":""} where the value for the output is True (if error bars exist) or False (if error bars do not exist). In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: True
# ChatGPT A: {"x-axis errors":"False"}
# {"explanation":"In the third-row, left-most panel, the plotted data are represented by vertical bars with no visible horizontal error bars or whiskers (no left/right uncertainty caps along the x-axis). Therefore, x-axis error bars do not appear to be present."}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the third row and left-most panel. Are there error bars on the data along the y-axis in this figure panel? Please format the output as a json as {"y-axis errors":""} where the value for the output is True (if error bars exist) or False (if error bars do not exist). In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: False
# ChatGPT A: {"y-axis errors":false}
#
# {"explanation":"In the third-row, left-most (bottom) panel, the data are shown as solid vertical bars without any visible vertical error-bar whiskers/caps along the y-axis. Therefore, y-axis error bars do not appear to be present."}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the third row and left-most panel. Please choose the distribution from the following list: [random, linear, gaussian mixture model]. What is the underlying distribution used to create the data in this figure panel? Please format the output as a json as {"distribution":""} for this figure panel, where the "distribution" value should be a string, calculated from the data values used to create the plot. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: linear
# ChatGPT A: {"distribution":"gaussian mixture model"}
# {"explanation":"In the bottom (third-row, left-most) panel, the bar heights across the x-bins form a broadly structured, smoothly varying pattern with clusters around a higher-density region rather than a straight-line trend (so not linear) and without the completely unstructured variability expected from purely random sampling (so more consistent with data generated from a Gaussian mixture model)."}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the top-left panel. What is the functional relationship between the x and y values in this figure panel? Please format the output as a json as {"relationship":[]} where each element of the list corresponds to a single line in the figure. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: ['random', 'random']
# ChatGPT A: {"relationship":["Approximately sinusoidal/periodic (y oscillates as x increases, with repeating peaks and troughs).","Approximately sinusoidal/periodic (y oscillates as x increases, roughly out of phase with the solid line)."]}
#
# {"explanation":"In the top-left panel (y = Theoretical Layers vs x = VLA), the plotted series do not show a monotonic trend; instead, y rises to maxima and then drops to minima repeatedly as x increases, forming an oscillatory (periodic) pattern. The dashed orange series follows a similar periodic behavior but appears shifted relative to the solid teal series (i.e., they are roughly out of phase)."}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the top-left panel. Please choose each relationship for each line from the following list for each line: [random, linear, gaussian mixture model]. What is the functional relationship between the x and y values in this figure panel? Please format the output as a json as {"relationship":[]} where each element of the list corresponds to a single line in the figure. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: ['random', 'random']
# ChatGPT A: {"relationship":["gaussian mixture model","gaussian mixture model"]}{"explanation":"In the top-left panel, the teal and orange series do not show a consistent monotonic trend or a roughly straight-line dependence of y on x (so it’s not linear). Instead, for different x values the y values appear to fall into multiple distinct vertical bands/clusters (a multimodal pattern), which is characteristic of data generated from a gaussian mixture model rather than purely random scatter."}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the top-left panel. Please note that there are a total of 2 lines in this plot, so the list should have a total of 2 entries.  Please choose each relationship for each line from the following list for each line: [random, linear, gaussian mixture model]. What is the functional relationship between the x and y values in this figure panel? Please format the output as a json as {"relationship":[]} where each element of the list corresponds to a single line in the figure. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: ['random', 'random']
# ChatGPT A: {"relationship":["random","random"]}
#
# {"explanation":"In the top-left panel, the two series (teal solid and orange dashed) show no consistent monotonic pattern or straight-line trend between VLA (x-axis) and the y-values. Instead, both lines fluctuate irregularly across x, clustering at varying y levels without a stable linear relationship, indicating a random relationship rather than linear or a clear Gaussian-mixture-shaped structure."}
#
# Prompt: I am going to show you an image. Now, the following question refers to the plot in the top-left panel. Please note that there are a total of 2 lines in this plot, so the list should have a total of 2 entries.  What is the functional relationship between the x and y values in this figure panel? Please format the output as a json as {"relationship":[]} where each element of the list corresponds to a single line in the figure. In addition to providing your answer, please provide your reasoning.  Include this as a separate JSON snippet formatted as {"explanation":""} and fill in your reasoning as a string.  Your answer should only include the answer JSON and the explanation JSON snippets, no other text.
#    Real A: ['random', 'random']
# ChatGPT A: {"relationship":["Non-linear oscillatory (approximately sinusoidal/periodic)","Non-linear oscillatory (approximately sinusoidal/periodic, phase-shifted relative to the other line)"]}
# {"explanation":"In the top-left panel, the two plotted lines do not follow a straight-line trend as x increases. Instead, each line rises and falls in an irregular but repeating way (peaks and troughs at different x intervals), indicating an oscillatory/periodic (non-linear) functional relationship rather than a linear one. The orange dashed line shows the same kind of oscillatory behavior but with a different offset/phase compared with the green solid line."}

# %%
#qa_in[0]
