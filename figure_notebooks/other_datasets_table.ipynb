# %%
table_dir = '~/LLM_VQA_MultiPanel/figure_notebooks/'

table_file = 'other_datasets_chart_asLatex.txt'

# %%
from astropy.table import Table
import os

table_dir = os.path.expanduser(table_dir)

# %%
# Read a .tex file or a string containing the table
dat = Table.read(table_dir+table_file, format='ascii.latex')

# Convert to Pandas DataFrame
df = dat.to_pandas()

# %%
# !ls ~/LLM_VQA_MultiPanel/figure_notebooks/*asLa*
# Out:
# /Users/jnaiman/LLM_VQA_MultiPanel/figure_notebooks/other_datasets_chart_asLatex.txt

# %%
df
# Out:
#                   Name      Date          Line           Bar          Sctr  \
# 0             FigureQA      2018  $\checkmark$  $\checkmark$            --
# 1           ChartLlama      2023            --            --  $\checkmark$
# 2   ChartAssistant/SFT      2024  $\checkmark$  $\checkmark$  $\checkmark$
# 3                 MMCA      2024  $\checkmark$  $\checkmark$  $\checkmark$
# 4   Chart2Text/to-text   2020/22  $\checkmark$  $\checkmark$  $\checkmark$
# 5            Chocolate      2024  $\checkmark$  $\checkmark$            --
# 6              Leaf-qa      2020  $\checkmark$  $\checkmark$  $\checkmark$
# 7              ChartQA      2022  $\checkmark$  $\checkmark$            --
# 8           ChartCheck      2023  $\checkmark$  $\checkmark$  $\checkmark$
# 9              OpenCQA      2022  $\checkmark$  $\checkmark$  $\checkmark$
# 10               MapQA      2022            --            --            --
# 11   MathVista/PaperQA      2023  $\checkmark$  $\checkmark$  $\checkmark$
# 12          SciGraphQA      2023            --            --            --
# 13             VisText      2023  $\checkmark$  $\checkmark$            --
# 14          Chart-Info  2019--24  $\checkmark$  $\checkmark$            --
# 15              DocVQA      2021  $\checkmark$  $\checkmark$            --
# 16             ChartFC      2023            --  $\checkmark$            --
# 17             RealCQA      2023  $\checkmark$  $\checkmark$  $\checkmark$
# 18         StructChart      2023  $\checkmark$  $\checkmark$            --
# 19           ChartSumm      2023  $\checkmark$  $\checkmark$            --
# 20            ChartOCR      2019  $\checkmark$  $\checkmark$            --
# 21              LineEX      2023  $\checkmark$            --            --
# 22              SciCap      2021            --  $\checkmark$  $\checkmark$
# 23           AutoChart      2021  $\checkmark$  $\checkmark$  $\checkmark$
# 24            Unichart      2023  $\checkmark$  $\checkmark$            --
# 25              PlotQA      2020  $\checkmark$  $\checkmark$  $\checkmark$
# 26              MatCha      2023  $\checkmark$  $\checkmark$            --
# 27                AI2D      2016            --            --            --
# 28                 TQA      2017            --            --            --
# 29          ChartQAPro      2025  $\checkmark$  $\checkmark$  $\checkmark$
# 30         EvoChart-QA      2025  $\checkmark$  $\checkmark$  $\checkmark$
# 31         ChartMuseum      2025  $\checkmark$  $\checkmark$  $\checkmark$
# 32         ChartGalaxy      2025  $\checkmark$  $\checkmark$  $\checkmark$
# 33          RefChartQA      2025  $\checkmark$  $\checkmark$            --
# 34            ChartDQA      2025  $\checkmark$  $\checkmark$  $\checkmark$
# 35           ChartQA-X      2025  $\checkmark$  $\checkmark$            --
# 36      MultiChartQA-R      2025  $\checkmark$  $\checkmark$  $\checkmark$
# 37       mChartQABench      2025  $\checkmark$  $\checkmark$            --
# 38   What Lies Beneath      2026            --            --            --
# 39           Chart-HQA      2026  $\checkmark$  $\checkmark$            --
#
#              Pie          Hist          Othr            BB     Data Link  \
# 0   $\checkmark$            --            --  $\checkmark$            --
# 1             --            --  $\checkmark$            --            --
# 2   $\checkmark$            --  $\checkmark$            --             P
# 3   $\checkmark$  $\checkmark$  $\checkmark$            --            --
# 4   $\checkmark$            --  $\checkmark$             P  $\checkmark$
# 5             --            --            --            --  $\checkmark$
# 6   $\checkmark$            --  $\checkmark$  $\checkmark$            --
# 7   $\checkmark$            --            --  $\checkmark$  $\checkmark$
# 8   $\checkmark$            --  $\checkmark$            --  $\checkmark$
# 9   $\checkmark$            --  $\checkmark$  $\checkmark$             P
# 10            --            --  $\checkmark$  $\checkmark$  $\checkmark$
# 11  $\checkmark$            --  $\checkmark$            --            --
# 12            --            --  $\checkmark$            --            --
# 13            --            --  $\checkmark$             P  $\checkmark$
# 14            --            --  $\checkmark$  $\checkmark$             P
# 15  $\checkmark$            --            --            --  $\checkmark$
# 16            --            --            --  $\checkmark$  $\checkmark$
# 17            --            --  $\checkmark$  $\checkmark$  $\checkmark$
# 18  $\checkmark$  $\checkmark$  $\checkmark$            --  $\checkmark$
# 19  $\checkmark$            --            --            --            --
# 20  $\checkmark$            --            --             P            --
# 21            --            --            --  $\checkmark$  $\checkmark$
# 22            --            --  $\checkmark$            --            --
# 23            --            --            --  $\checkmark$            --
# 24  $\checkmark$            --            --             P            --
# 25            --            --            --  $\checkmark$  $\checkmark$
# 26            --            --  $\checkmark$            --  $\checkmark$
# 27            --            --  $\checkmark$            --            --
# 28            --            --  $\checkmark$  $\checkmark$  $\checkmark$
# 29  $\checkmark$            --  $\checkmark$            --            --
# 30  $\checkmark$            --  $\checkmark$            --            --
# 31  $\checkmark$            --  $\checkmark$            --            --
# 32  $\checkmark$            --  $\checkmark$            --  $\checkmark$
# 33  $\checkmark$            --            --  $\checkmark$             P
# 34  $\checkmark$  $\checkmark$  $\checkmark$            --  $\checkmark$
# 35  $\checkmark$            --            --            --            --
# 36  $\checkmark$            --  $\checkmark$            --            --
# 37  $\checkmark$            --  $\checkmark$            --            --
# 38            --  $\checkmark$            --  $\checkmark$  $\checkmark$
# 39  $\checkmark$            --  $\checkmark$            --            --
#
#       MultiPanel                                        Citation(s)
# 0             --                         \cite{kahou_figureqa_2018}
# 1             --                         \cite{han_chartllama_2023}
# 2             --                    \cite{meng_chartassistant_2024}
# 3             --                                \cite{liu_mmc_2024}
# 4             --  \cite{kantharaj_chart--text_2022,obeid_chart--...
# 5             --                            \cite{huang_lvlms_2024}
# 6             --                       \cite{chaudhry_leaf-qa_2020}
# 7             --                          \cite{masry_chartqa_2022}
# 8             --                      \cite{akhtar_chartcheck_2024}
# 9             --                      \cite{kantharaj_opencqa_2022}
# 10            --                            \cite{chang_mapqa_2022}
# 11             P                           \cite{lu_mathvista_2023}
# 12             P                          \cite{li_scigraphqa_2023}
# 13            --                           \cite{tang_vistext_2023}
# 14             P  \cite{davila2022icpr,davila_chart-info_2025,da...
# 15             P                          \cite{mathew_docvqa_2021}
# 16            --                         \cite{akhtar_reading_2023}
# 17            --                          \cite{ahmed_realcqa_2023}
# 18            --                        \cite{xia_structchart_2024}
# 19            --                       \cite{rahman_chartsumm_2023}
# 20            --                           \cite{luo_chartocr_2021}
# 21            --                               \cite{p_lineex_2023}
# 22             P                             \cite{hsu_scicap_2021}
# 23            --                          \cite{zhu_autochart_2021}
# 24            --                         \cite{masry_unichart_2023}
# 25            --                         \cite{methani_plotqa_2020}
# 26            --                             \cite{liu_matcha_2023}
# 27            --                       \cite{kembhavi_diagram_2016}
# 28            --                           \cite{kembhavi_are_2017}
# 29  $\checkmark$                       \cite{masry_chartqapro_2025}
# 30            --                         \cite{huang_evochart_2025}
# 31             P                       \cite{tang_chartmuseum_2025}
# 32  $\checkmark$                         \cite{li_chartgalaxy_2025}
# 33            --                       \cite{vogel_refchartqa_2025}
# 34            --                             \cite{fan_-depth_2025}
# 35            --                        \cite{hegde_chartqa-x_2025}
# 36  $\checkmark$               \cite{qiyuanfan_multichartqa-r_2025}
# 37            --                           \cite{wei_mchartqa_2026}
# 38            --                            \cite{naiman_what_2026}
# 39            --                         \cite{chen_chart-hqa_2025}
